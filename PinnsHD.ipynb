# %% [markdown]
# ## Physics Informed Neural Networks to Approximate Solution of PDEs

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch.optim as optim
import torch
from torch.utils.data import DataLoader

# Adapt this import to your specific directory tree.
from Common import NeuralNet, MultiVariatePoly
import time
torch.autograd.set_detect_anomaly(True)
torch.manual_seed(128)

# %% [markdown]
# Consider the one-dimensional parametric heat equation:
#
# $$
# u_t(t, x, \mu) = u_{xx}(t, x, \mu), \quad t\in[0,T], ~x\in [-1,1], ~\mu\in [-1,1]^d
# $$
#
# where the parametric nature of the PDE stems from the initial condition
#
# $$
# u(0, x, \mu) = u_0(x, \mu) = \sum_{m}^d u_0^m(x, \mu_m) = - \frac{1}{d}\sum_{m=1}^d \mu_m\sin(\pi m x )/m^{0.5}
# $$
#
# with
#
# $$
# u_0^m(x, \mu_m) = - \mu_m\sin(\pi m x )/m^{0.5}
# $$
#
# Similarly to the previous tutorials, consider zero Dirichlet BC:
# $$
# u_b(t, -1, \mu)=u_b(t,1, \mu)=0,
# $$
#
# We want to obtain an approximate solution of the heat equation $u : [0,T]\times[-1,1]\times[-1,1]^d  \mapsto R$ with physics informed neural networks (PINNs).
#
# To do so, we consider the following ansatz for the solution of the PDE:
#
# $$
# \bar{u}_\theta(t,x,\mu) =  \frac{1}{d}\sum_{m=1}^d u_0^m(x, \mu_m)(1 - t u^m_{\theta}(t,x,\mu)) \approx u(t,x, \mu)
# $$
# with $u_\theta(t,x,\mu):\mathbb{R}^{2+d}\mapsto \mathbb{R}^{d}$, $u_\theta(t,x,\mu) =(u^1_\theta(t,x,\mu), ..., u^d_\theta(t,x,\mu))$ being a feedforward dense neural network with tunable parameters $\theta$.
#
# This ansatz is a natural choice for this type of problem, given the nature of the initial condition, which is the superposition of different functions $u_0^m(x, \mu_m)$ and the linearity of the PDE. As a consequence, the PDE solution is the superposition of the solutions of the PDE with initial conditions given by $u_0^m(x, \mu_m)$.
#
# Define the following residuals:
#
# - Interior residual given by,
#
# \begin{equation}
#          r_{int,\theta}(t, x, \mu):=  \bar{u}_\theta(t, x, \mu) - \bar{u}_{\theta, xx}(t, x, \mu), \quad \forall ~t \in [0,T],~ x \in [-1,1], ~\mu \in [-1,1]^d.
# \end{equation}
#
# - Spatial boundary residual given by,
#
# \begin{equation}
#     r_{sb,\theta}(t,-1,\mu):= \bar{u}_{\theta}(t,-1, \mu)- u_b(t,-1, \mu), \quad r_{sb,\theta}(t,1, \mu):= \bar{u}_{\theta}(t,1, \mu)- u_b(t,1, \mu), \quad \forall t \in (0,T], ~\mu \in [-1,1]^d .
# \end{equation}
#
#
#    - Temporal boundary residual given by,
#
#         $$r_{tb,\theta}(x,\mu):= \bar{u}_{\theta}(x,0,\mu) - u_0(x,\mu), \quad \forall x \in [-1,1], ~\mu \in [-1,1]^d.$$
#
# Observe that given the definition of $\bar{u}$, the boundaries residuals are identically zero.
#
#
# Therefore, we only need to compute the interior loss given the training data
#
# $$
# S_{int} =\{y_n\}, \quad 1 \leq n \leq N_{int},\quad y_n = (x,t, \mu)_n \in [0,T]\times[-1,1]\times[-1,1]^d,
# $$
#
# $$
# L_{int}(\theta) = \frac{1}{N_{int}}\sum_{i=1}^{N_{int}}r_{int,\theta}^2(y_n)
# $$
#
# and solve the minimization problem
#
# $$
# \theta^\ast = argmin_{\theta} \Big(L_{int}(\theta)\Big)
# $$

# %%
class HardBCPinns(torch.nn.Module):

    def __init__(self, ic, u_tilde):
        super().__init__()
        self.ic = ic
        self.u_tilde = u_tilde

    def forward(self, x):
        time_coord = x[:, 0].reshape(-1, )

        u0 = self.ic(x[:, 1:])
        u_tilde = self.u_tilde(x)
        sol = torch.sum((1 - time_coord[:, None] * u_tilde) * u0, -1)

        return sol.reshape(-1, 1)

class Pinns:
    def __init__(self, n_int_, n_sb_, n_tb_):
        self.n_int = n_int_
        self.n_sb = n_sb_
        self.n_tb = n_tb_

        # Extrema of the solution domain (t,x) in [0,0.1]x[-1,1]
        self.domain_extrema = torch.tensor([[0, 0.1],  # Time dimension
                                            [-1, 1]])  # Space dimension

        self.p = 5
        self.parameters_extrema = torch.ones((self.p, 2))
        self.parameters_extrema[:, 0] = -1

        self.domain_extrema = torch.cat(
            (self.domain_extrema, self.parameters_extrema), 0)

        # Number of space dimensions
        self.space_dimensions = 1

        # FF Dense NN to approximate the solution of the underlying heat equation
        self.nn = NeuralNet(input_dimension=2 + self.p,
                            output_dimension=self.p,
                            n_hidden_layers=4,
                            neurons=20,
                            regularization_param=0.,
                            regularization_exp=2.,
                            retrain_seed=42)

        self.approximate_solution = HardBCPinns(
            self.get_initial_condition_modes, self.nn)

        # Generator of Sobol sequences
        self.soboleng = torch.quasirandom.SobolEngine(
            dimension=self.domain_extrema.shape[0])

        # Training sets S_sb, S_tb, S_int as torch dataloader
        self.training_set_sb, self.training_set_tb, self.training_set_int = self.assemble_datasets()

    ################################################################################################
    # Function to linearly transform a tensor whose value are between 0 and 1
    # to a tensor whose values are between the domain extrema
    def convert(self, tens):
        assert (tens.shape[1] == self.domain_extrema.shape[0])
        return tens * (self.domain_extrema[:, 1] - self.domain_extrema[:, 0]) + self.domain_extrema[:, 0]

    # Initial condition to solve the heat equation u0(x)=-sin(pi x)
    def initial_condition(self, inputs):
        t0 = torch.full((inputs.shape[0], 1), self.domain_extrema[0, 0])
        inputs = torch.cat((t0, inputs), 1)
        return self.exact_solution(inputs)

    def get_initial_condition_modes(self, inputs):
        x = inputs[:, 0]
        mu = inputs[:, 1:]
        u = torch.zeros((inputs.shape[0], self.p))
        for i in range(1, self.p + 1):
            u[:, i-1] = -mu[:, i - 1]/self.p * torch.sin(np.pi * x * i) / i ** 0.5
        return u

    # Exact solution for the heat equation ut = u_xx with the IC above
    def exact_solution(self, inputs):
        t = inputs[:, 0]
        x = inputs[:, 1]
        mu = inputs[:, 2:]
        u = 0
        for i in range(1, self.p + 1):
            u = u - torch.exp(-(np.pi * i) ** 2 * t) * mu[:, i - 1]/self.p * torch.sin(np.pi * x * i) / i ** 0.5

        return u

    ################################################################################################
    # Function returning the input-output tensor required to assemble the training set S_tb corresponding to the temporal boundary
    def add_temporal_boundary_points(self):
        t0 = self.domain_extrema[0, 0]
        input_tb = self.convert(self.soboleng.draw(self.n_tb))
        input_tb[:, 0] = torch.full(input_tb[:, 0].shape, t0)
        output_tb = self.initial_condition(input_tb[:, 1:]).reshape(-1, 1)

        return input_tb, output_tb

    # Function returning the input-output tensor required to assemble the training set S_sb corresponding to the spatial boundary
    def add_spatial_boundary_points(self):
        x0 = self.domain_extrema[1, 0]
        xL = self.domain_extrema[1, 1]

        input_sb = self.convert(self.soboleng.draw(self.n_sb))

        input_sb_0 = torch.clone(input_sb)
        input_sb_0[:, 1] = torch.full(input_sb_0[:, 1].shape, x0)

        input_sb_L = torch.clone(input_sb)
        input_sb_L[:, 1] = torch.full(input_sb_L[:, 1].shape, xL)

        output_sb_0 = torch.zeros((input_sb.shape[0], 1))
        output_sb_L = torch.zeros((input_sb.shape[0], 1))

        return torch.cat([input_sb_0, input_sb_L], 0), torch.cat([output_sb_0, output_sb_L], 0)

    #  Function returning the input-output tensor required to assemble the training set S_int corresponding to the interior domain where the PDE is enforced
    def add_interior_points(self):
        input_int = self.convert(self.soboleng.draw(self.n_int))
        output_int = torch.zeros((input_int.shape[0], 1))
        return input_int, output_int

    # Function returning the training sets S_sb, S_tb, S_int as dataloader
    def assemble_datasets(self):
        input_sb, output_sb = self.add_spatial_boundary_points()  # S_sb
        input_tb, output_tb = self.add_temporal_boundary_points()  # S_tb
        input_int, output_int = self.add_interior_points()  # S_int

        training_set_sb = DataLoader(torch.utils.data.TensorDataset(input_sb, output_sb), batch_size=2 * self.space_dimensions * self.n_sb, shuffle=False)
        training_set_tb = DataLoader(torch.utils.data.TensorDataset(input_tb, output_tb), batch_size=self.n_tb, shuffle=False)
        training_set_int = DataLoader(torch.utils.data.TensorDataset(input_int, output_int), batch_size=self.n_int, shuffle=False)

        return training_set_sb, training_set_tb, training_set_int

    ################################################################################################
    # Function to compute the terms required in the definition of the TEMPORAL boundary residual
    def apply_initial_condition(self, input_tb):
        u_pred_tb = self.approximate_solution(input_tb)
        return u_pred_tb

    # Function to compute the terms required in the definition of the SPATIAL boundary residual
    def apply_boundary_conditions(self, input_sb):
        u_pred_sb = self.approximate_solution(input_sb)

        return u_pred_sb

    # Function to compute the PDE residuals
    def compute_pde_residual(self, input_int):
        input_int.requires_grad = True
        u = self.approximate_solution(input_int)

        # grad compute the gradient of a "SCALAR" function L with respect to some input nxm TENSOR Z=[[x1, y1],[x2,y2],[x3,y3],...,[xn,yn]], m=2
        # it returns grad_L = [[dL/dx1, dL/dy1],[dL/dx2, dL/dy2],[dL/dx3, dL/dy3],...,[dL/dxn, dL/dyn]]
        # Note: pytorch considers a tensor [u1, u2,u3, ... ,un] a vectorial function
        # whereas sum_u = u1 + u2 u3 + u4 + ... + un as a "scalar" one

        # In our case ui = u(xi), therefore the line below returns:
        # grad_u = [[dsum_u/dx1, dsum_u/dy1],[dsum_u/dx2, dsum_u/dy2],[dsum_u/dx3, dL/dy3],...,[dsum_u/dxm, dsum_u/dyn]]
        # and dsum_u/dxi = d(u1 + u2 u3 + u4 + ... + un)/dxi = d(u(x1) + u(x2) u3(x3) + u4(x4) + ... + u(xn))/dxi = dui/dxi
        grad_u = torch.autograd.grad(u.sum(), input_int, create_graph=True)[0]
        grad_u_t = grad_u[:, 0]
        grad_u_x = grad_u[:, 1]
        grad_u_xx = torch.autograd.grad(grad_u_x.sum(), input_int, create_graph=True)[0][:, 1]

        residual = grad_u_t - grad_u_xx
        return residual.reshape(-1, )

    # Function to compute the total loss (weighted sum of spatial boundary loss, temporal boundary loss and interior loss)
    def compute_loss(self, inp_train_sb, u_train_sb, inp_train_tb, u_train_tb, inp_train_int, verbose=True):
        u_pred_sb = self.apply_boundary_conditions(inp_train_sb)
        u_pred_tb = self.apply_initial_condition(inp_train_tb)

        assert (u_pred_sb.shape[1] == u_train_sb.shape[1])
        assert (u_pred_tb.shape[1] == u_train_tb.shape[1])

        r_int = self.compute_pde_residual(inp_train_int)
        r_sb = u_train_sb - u_pred_sb
        r_tb = u_train_tb - u_pred_tb

        loss_sb = torch.mean(abs(r_sb) ** 2)
        loss_tb = torch.mean(abs(r_tb) ** 2)
        loss_int = torch.mean(abs(r_int) ** 2)

        loss_u = loss_sb + loss_tb

        # Loss is given only by the interior one since the boundary and initial conditions are automatically satisfied.
        loss = torch.log10(loss_int)
        if verbose:
           print(
               "Total loss: ", round(loss.item(), 4),
                "| PDE Loss: ", round(torch.log10(loss_int).item(), 4), "| Function Loss: ", round(torch.log10(loss_u).item(), 4))

        return loss

    ################################################################################################
    def fit(self, num_epochs, optimizer, verbose=True):
        history = list()

        # Loop over epochs
        for epoch in range(num_epochs):
            if verbose: print("################################ ", epoch, " ################################")

            for j, ((inp_train_sb, u_train_sb), (inp_train_tb, u_train_tb), (inp_train_int, u_train_int)) in enumerate(zip(self.training_set_sb, self.training_set_tb, self.training_set_int)):
                def closure():
                    optimizer.zero_grad()
                    loss = self.compute_loss(inp_train_sb, u_train_sb, inp_train_tb, u_train_tb, inp_train_int, verbose=verbose)
                    loss.backward()

                    history.append(loss.item())
                    return loss

                optimizer.step(closure=closure)

        print('Final Loss: ', history[-1])

        return history

    ################################################################################################
    def plotting(self):
        t = torch.linspace(0, 1, 50)
        x = torch.linspace(0, 1, 50)
        input_tx = torch.cartesian_prod(t, x)

        for i in range(5):
            mu = torch.rand((1, self.p))
            mu = mu.repeat(input_tx.shape[0], 1)

            inputs = torch.cat((input_tx, mu), -1)
            inputs = self.convert(inputs)

            output = self.approximate_solution(inputs).reshape(50, 50)
            exact_output = self.exact_solution(inputs).reshape(50, 50)

            fig, axs = plt.subplots(1, 2, figsize=(16, 8), dpi=150)
            im1 = axs[0].contourf(x, t, exact_output.detach(), cmap="jet", levels=200)
            axs[0].set_xlabel("x")
            axs[0].set_ylabel("t")
            plt.colorbar(im1, ax=axs[0])
            axs[0].grid(True, which="both", ls=":")
            im2 = axs[1].contourf(x, t, output.detach(), cmap="jet", levels=200)
            axs[1].set_xlabel("x")
            axs[1].set_ylabel("t")
            plt.colorbar(im2, ax=axs[1])
            axs[1].grid(True, which="both", ls=":")
            axs[0].set_title("Exact Solution")
            axs[1].set_title("Approximate Solution")

            plt.show()

            err = (torch.mean((output - exact_output) ** 2) / torch.mean(exact_output ** 2)) ** 0.5 * 100
            print("L2 Relative Error Norm: ", err.item(), "%")

# %%
# Solve the heat equation:
# u_t = u_xx, (t,x) in [0, 0.1]x[-1,1]
# with zero dirichlet BC and
# u(x,0)= -sin(pi x)

n_int = 8192
n_sb = 4
n_tb = 4

pinn = Pinns(n_int, n_sb, n_tb)

# %%
# Plot the input training points
input_sb_, output_sb_ = pinn.add_spatial_boundary_points()
input_tb_, output_tb_ = pinn.add_temporal_boundary_points()
input_int_, output_int_ = pinn.add_interior_points()

plt.figure(figsize=(16, 8), dpi=150)
plt.scatter(input_sb_[:, 1].detach().numpy(), input_sb_[:, 0].detach().numpy(), label="Boundary Points")
plt.scatter(input_int_[:, 1].detach().numpy(), input_int_[:, 0].detach().numpy(), label="Interior Points")
plt.scatter(input_tb_[:, 1].detach().numpy(), input_tb_[:, 0].detach().numpy(), label="Initial Points")
plt.xlabel("x")
plt.ylabel("t")
plt.legend()
plt.show()

# %%
n_epochs = 1
optimizer_LBFGS = optim.LBFGS(pinn.approximate_solution.parameters(),
                              lr=float(0.5),
                              max_iter=10000,
                              max_eval=50000,
                              history_size=150,
                              line_search_fn="strong_wolfe",
                              tolerance_change=1.0 * np.finfo(float).eps)
optimizer_ADAM = optim.Adam(pinn.approximate_solution.parameters(),
                            lr=float(0.005))

# %%
hist = pinn.fit(num_epochs=n_epochs,
                optimizer=optimizer_LBFGS,
                verbose=True)

plt.figure(dpi=150)
plt.grid(True, which="both", ls=":")
plt.plot(np.arange(1, len(hist) + 1), hist, label="Train Loss")
plt.xscale("log")
plt.legend()
# Out:
# ################################  0  ################################
# Total loss:  2.1666 | PDE Loss:  2.1666 | Function Loss:  -14.9748
# Total loss:  2.162 | PDE Loss:  2.162 | Function Loss:  -14.9809
# Total loss:  2.122 | PDE Loss:  2.122 | Function Loss:  -15.0347
# Total loss:  2.0512 | PDE Loss:  2.0512 | Function Loss:  -15.1177
# Total loss:  1.929 | PDE Loss:  1.929 | Function Loss:  -15.238
# Total loss:  1.6435 | PDE Loss:  1.6435 | Function Loss:  -15.5016
# Total loss:  1.5395 | PDE Loss:  1.5395 | Function Loss:  -15.535
# Total loss:  1.5118 | PDE Loss:  1.5118 | Function Loss:  -15.5227
# Total loss:  1.5054 | PDE Loss:  1.5054 | Function Loss:  -15.518
# Total loss:  1.4931 | PDE Loss:  1.4931 | Function Loss:  -15.5122
# Total loss:  1.4887 | PDE Loss:  1.4887 | Function Loss:  -15.5038
# Total loss:  1.4868 | PDE Loss:  1.4868 | Function Loss:  -15.5017
# Total loss:  1.4858 | PDE Loss:  1.4858 | Function Loss:  -15.5005
# Total loss:  1.4854 | PDE Loss:  1.4854 | Function Loss:  -15.5033
# Total loss:  1.4852 | PDE Loss:  1.4852 | Function Loss:  -15.5046
# Total loss:  1.4852 | PDE Loss:  1.4852 | Function Loss:  -15.5064
# Total loss:  1.4851 | PDE Loss:  1.4851 | Function Loss:  -15.5073
# Total loss:  1.4851 | PDE Loss:  1.4851 | Function Loss:  -15.5079
# Total loss:  1.4851 | PDE Loss:  1.4851 | Function Loss:  -15.5084
# Total loss:  1.4851 | PDE Loss:  1.4851 | Function Loss:  -15.5087
# Total loss:  1.4851 | PDE Loss:  1.4851 | Function Loss:  -15.5092
# Total loss:  1.4851 | PDE Loss:  1.4851 | Function Loss:  -15.5097
# Total loss:  1.4851 | PDE Loss:  1.4851 | Function Loss:  -15.5103
# Total loss:  1.485 | PDE Loss:  1.485 | Function Loss:  -15.5107
# Total loss:  1.485 | PDE Loss:  1.485 | Function Loss:  -15.5116
# Total loss:  1.4849 | PDE Loss:  1.4849 | Function Loss:  -15.5123
# Total loss:  1.4848 | PDE Loss:  1.4848 | Function Loss:  -15.5131
# Total loss:  1.4847 | PDE Loss:  1.4847 | Function Loss:  -15.5123
# Total loss:  1.4845 | PDE Loss:  1.4845 | Function Loss:  -15.5032
# Total loss:  1.4843 | PDE Loss:  1.4843 | Function Loss:  -15.5062
# Total loss:  1.4841 | PDE Loss:  1.4841 | Function Loss:  -15.508
# Total loss:  1.4837 | PDE Loss:  1.4837 | Function Loss:  -15.5097
# Total loss:  1.4833 | PDE Loss:  1.4833 | Function Loss:  -15.5121
# Total loss:  1.483 | PDE Loss:  1.483 | Function Loss:  -15.5209
# Total loss:  1.482 | PDE Loss:  1.482 | Function Loss:  -15.5191
# Total loss:  1.486 | PDE Loss:  1.486 | Function Loss:  -15.5501
# Total loss:  1.481 | PDE Loss:  1.481 | Function Loss:  -15.5299
# Total loss:  1.4801 | PDE Loss:  1.4801 | Function Loss:  -15.5364
# Total loss:  1.4783 | PDE Loss:  1.4783 | Function Loss:  -15.5443
# Total loss:  1.476 | PDE Loss:  1.476 | Function Loss:  -15.5421
# Total loss:  1.4739 | PDE Loss:  1.4739 | Function Loss:  -15.5421
# Total loss:  1.4719 | PDE Loss:  1.4719 | Function Loss:  -15.5426
# Total loss:  1.4711 | PDE Loss:  1.4711 | Function Loss:  -15.5459
# Total loss:  1.4695 | PDE Loss:  1.4695 | Function Loss:  -15.5478
# Total loss:  1.4681 | PDE Loss:  1.4681 | Function Loss:  -15.5458
# Total loss:  1.4662 | PDE Loss:  1.4662 | Function Loss:  -15.5433
# Total loss:  1.4652 | PDE Loss:  1.4652 | Function Loss:  -15.547
# Total loss:  1.4629 | PDE Loss:  1.4629 | Function Loss:  -15.5422
# Total loss:  1.4579 | PDE Loss:  1.4579 | Function Loss:  -15.5501
# Total loss:  1.4557 | PDE Loss:  1.4557 | Function Loss:  -15.5502
# Total loss:  1.4535 | PDE Loss:  1.4535 | Function Loss:  -15.5535
# Total loss:  1.4498 | PDE Loss:  1.4498 | Function Loss:  -15.5639
# Total loss:  1.4454 | PDE Loss:  1.4454 | Function Loss:  -15.5846
# Total loss:  1.4376 | PDE Loss:  1.4376 | Function Loss:  -15.5942
# Total loss:  1.4297 | PDE Loss:  1.4297 | Function Loss:  -15.5776
# Total loss:  1.422 | PDE Loss:  1.422 | Function Loss:  -15.5542
# Total loss:  1.407 | PDE Loss:  1.407 | Function Loss:  -15.5406
# Total loss:  1.4613 | PDE Loss:  1.4613 | Function Loss:  -15.5331
# Total loss:  1.3846 | PDE Loss:  1.3846 | Function Loss:  -15.5487
# Total loss:  1.5196 | PDE Loss:  1.5196 | Function Loss:  -15.5275
# Total loss:  1.3714 | PDE Loss:  1.3714 | Function Loss:  -15.5518
# Total loss:  1.3511 | PDE Loss:  1.3511 | Function Loss:  -15.5819
# Total loss:  1.3348 | PDE Loss:  1.3348 | Function Loss:  -15.5761
# Total loss:  1.3249 | PDE Loss:  1.3249 | Function Loss:  -15.5957
# Total loss:  1.3224 | PDE Loss:  1.3224 | Function Loss:  -15.6461
# Total loss:  1.3147 | PDE Loss:  1.3147 | Function Loss:  -15.6319
# Total loss:  1.3133 | PDE Loss:  1.3133 | Function Loss:  -15.6529
# Total loss:  1.3097 | PDE Loss:  1.3097 | Function Loss:  -15.6451
# Total loss:  1.307 | PDE Loss:  1.307 | Function Loss:  -15.6463
# Total loss:  1.2997 | PDE Loss:  1.2997 | Function Loss:  -15.6391
# Total loss:  1.294 | PDE Loss:  1.294 | Function Loss:  -15.6416
# Total loss:  1.2843 | PDE Loss:  1.2843 | Function Loss:  -15.6467
# Total loss:  1.2771 | PDE Loss:  1.2771 | Function Loss:  -15.6528
# Total loss:  1.2836 | PDE Loss:  1.2836 | Function Loss:  -15.6749
# Total loss:  1.2701 | PDE Loss:  1.2701 | Function Loss:  -15.664
# Total loss:  1.2661 | PDE Loss:  1.2661 | Function Loss:  -15.6704
# Total loss:  1.2571 | PDE Loss:  1.2571 | Function Loss:  -15.7092
# Total loss:  1.2434 | PDE Loss:  1.2434 | Function Loss:  -15.6825
# Total loss:  1.2268 | PDE Loss:  1.2268 | Function Loss:  -15.6875
# Total loss:  1.2116 | PDE Loss:  1.2116 | Function Loss:  -15.6628
# Total loss:  1.2374 | PDE Loss:  1.2374 | Function Loss:  -15.7504
# Total loss:  1.2012 | PDE Loss:  1.2012 | Function Loss:  -15.7126
# Total loss:  1.1858 | PDE Loss:  1.1858 | Function Loss:  -15.7008
# Total loss:  1.1677 | PDE Loss:  1.1677 | Function Loss:  -15.712
# Total loss:  1.1234 | PDE Loss:  1.1234 | Function Loss:  -15.7209
# Total loss:  1.1046 | PDE Loss:  1.1046 | Function Loss:  -15.7485
# Total loss:  1.0835 | PDE Loss:  1.0835 | Function Loss:  -15.6999
# Total loss:  1.0456 | PDE Loss:  1.0456 | Function Loss:  -15.7546
# Total loss:  1.0286 | PDE Loss:  1.0286 | Function Loss:  -15.8181
# Total loss:  1.0147 | PDE Loss:  1.0147 | Function Loss:  -15.8397
# Total loss:  0.9963 | PDE Loss:  0.9963 | Function Loss:  -15.8471
# Total loss:  0.9727 | PDE Loss:  0.9727 | Function Loss:  -15.8694
# Total loss:  0.9389 | PDE Loss:  0.9389 | Function Loss:  -15.8827
# Total loss:  0.9156 | PDE Loss:  0.9156 | Function Loss:  -15.8821
# Total loss:  0.893 | PDE Loss:  0.893 | Function Loss:  -15.8883
# Total loss:  0.8806 | PDE Loss:  0.8806 | Function Loss:  -15.8638
# Total loss:  0.8693 | PDE Loss:  0.8693 | Function Loss:  -15.8894
# Total loss:  0.8579 | PDE Loss:  0.8579 | Function Loss:  -15.8886
# Total loss:  0.8522 | PDE Loss:  0.8522 | Function Loss:  -15.8898
# Total loss:  0.8472 | PDE Loss:  0.8472 | Function Loss:  -15.8796
# Total loss:  0.8401 | PDE Loss:  0.8401 | Function Loss:  -15.8591
# Total loss:  0.8304 | PDE Loss:  0.8304 | Function Loss:  -15.8445
# Total loss:  0.8197 | PDE Loss:  0.8197 | Function Loss:  -15.8205
# Total loss:  0.7941 | PDE Loss:  0.7941 | Function Loss:  -15.788
# Total loss:  0.7591 | PDE Loss:  0.7591 | Function Loss:  -15.7575
# Total loss:  0.736 | PDE Loss:  0.736 | Function Loss:  -15.7562
# Total loss:  0.705 | PDE Loss:  0.705 | Function Loss:  -15.7923
# Total loss:  0.7081 | PDE Loss:  0.7081 | Function Loss:  -15.818
# Total loss:  0.6842 | PDE Loss:  0.6842 | Function Loss:  -15.8024
# Total loss:  0.6584 | PDE Loss:  0.6584 | Function Loss:  -15.8257
# Total loss:  0.6362 | PDE Loss:  0.6362 | Function Loss:  -15.8363
# Total loss:  0.5991 | PDE Loss:  0.5991 | Function Loss:  -15.8594
# Total loss:  0.5617 | PDE Loss:  0.5617 | Function Loss:  -15.8735
# Total loss:  0.5746 | PDE Loss:  0.5746 | Function Loss:  -15.8873
# Total loss:  0.5381 | PDE Loss:  0.5381 | Function Loss:  -15.8797
# Total loss:  0.5088 | PDE Loss:  0.5088 | Function Loss:  -15.8961
# Total loss:  0.4834 | PDE Loss:  0.4834 | Function Loss:  -15.8935
# Total loss:  0.4846 | PDE Loss:  0.4846 | Function Loss:  -15.9005
# Total loss:  0.4711 | PDE Loss:  0.4711 | Function Loss:  -15.8974
# Total loss:  0.4511 | PDE Loss:  0.4511 | Function Loss:  -15.9028
# Total loss:  0.4413 | PDE Loss:  0.4413 | Function Loss:  -15.9139
# Total loss:  0.4514 | PDE Loss:  0.4514 | Function Loss:  -15.8965
# Total loss:  0.4324 | PDE Loss:  0.4324 | Function Loss:  -15.9076
# Total loss:  0.4215 | PDE Loss:  0.4215 | Function Loss:  -15.9025
# Total loss:  0.4147 | PDE Loss:  0.4147 | Function Loss:  -15.9011
# Total loss:  0.4083 | PDE Loss:  0.4083 | Function Loss:  -15.9102
# Total loss:  0.4009 | PDE Loss:  0.4009 | Function Loss:  -15.9072
# Total loss:  0.3879 | PDE Loss:  0.3879 | Function Loss:  -15.9033
# Total loss:  0.3724 | PDE Loss:  0.3724 | Function Loss:  -15.9084
# Total loss:  0.3576 | PDE Loss:  0.3576 | Function Loss:  -15.9112
# Total loss:  0.3384 | PDE Loss:  0.3384 | Function Loss:  -15.912
# Total loss:  0.3162 | PDE Loss:  0.3162 | Function Loss:  -15.9159
# Total loss:  0.2904 | PDE Loss:  0.2904 | Function Loss:  -15.9114
# Total loss:  0.2701 | PDE Loss:  0.2701 | Function Loss:  -15.9086
# Total loss:  0.2472 | PDE Loss:  0.2472 | Function Loss:  -15.9063
# Total loss:  0.2341 | PDE Loss:  0.2341 | Function Loss:  -15.9065
# Total loss:  0.2233 | PDE Loss:  0.2233 | Function Loss:  -15.9052
# Total loss:  0.213 | PDE Loss:  0.213 | Function Loss:  -15.9084
# Total loss:  0.2063 | PDE Loss:  0.2063 | Function Loss:  -15.9096
# Total loss:  0.1973 | PDE Loss:  0.1973 | Function Loss:  -15.9163
# Total loss:  0.1908 | PDE Loss:  0.1908 | Function Loss:  -15.9181
# Total loss:  0.1825 | PDE Loss:  0.1825 | Function Loss:  -15.917
# Total loss:  0.1752 | PDE Loss:  0.1752 | Function Loss:  -15.9242
# Total loss:  0.1692 | PDE Loss:  0.1692 | Function Loss:  -15.924
# Total loss:  0.163 | PDE Loss:  0.163 | Function Loss:  -15.9256
# Total loss:  0.1558 | PDE Loss:  0.1558 | Function Loss:  -15.93
# Total loss:  0.1482 | PDE Loss:  0.1482 | Function Loss:  -15.9336
# Total loss:  0.1413 | PDE Loss:  0.1413 | Function Loss:  -15.936
# Total loss:  0.1319 | PDE Loss:  0.1319 | Function Loss:  -15.9374
# Total loss:  0.1132 | PDE Loss:  0.1132 | Function Loss:  -15.939
# Total loss:  0.1016 | PDE Loss:  0.1016 | Function Loss:  -15.9391
# Total loss:  0.0953 | PDE Loss:  0.0953 | Function Loss:  -15.9351
# Total loss:  0.0879 | PDE Loss:  0.0879 | Function Loss:  -15.9372
# Total loss:  0.0852 | PDE Loss:  0.0852 | Function Loss:  -15.9397
# Total loss:  0.0831 | PDE Loss:  0.0831 | Function Loss:  -15.9472
# Total loss:  0.0782 | PDE Loss:  0.0782 | Function Loss:  -15.9467
# Total loss:  0.0719 | PDE Loss:  0.0719 | Function Loss:  -15.9455
# Total loss:  0.0654 | PDE Loss:  0.0654 | Function Loss:  -15.945
# Total loss:  0.0603 | PDE Loss:  0.0603 | Function Loss:  -15.9455
# Total loss:  0.0546 | PDE Loss:  0.0546 | Function Loss:  -15.9467
# Total loss:  0.0446 | PDE Loss:  0.0446 | Function Loss:  -15.9489
# Total loss:  0.0326 | PDE Loss:  0.0326 | Function Loss:  -15.9492
# Total loss:  0.0224 | PDE Loss:  0.0224 | Function Loss:  -15.9525
# Total loss:  0.0128 | PDE Loss:  0.0128 | Function Loss:  -15.9511
# Total loss:  0.003 | PDE Loss:  0.003 | Function Loss:  -15.9494
# Total loss:  -0.0024 | PDE Loss:  -0.0024 | Function Loss:  -15.9461
# Total loss:  -0.0121 | PDE Loss:  -0.0121 | Function Loss:  -15.9471
# Total loss:  -0.02 | PDE Loss:  -0.02 | Function Loss:  -15.9482
# Total loss:  -0.0232 | PDE Loss:  -0.0232 | Function Loss:  -15.9439
# Total loss:  -0.0351 | PDE Loss:  -0.0351 | Function Loss:  -15.9447
# Total loss:  -0.0445 | PDE Loss:  -0.0445 | Function Loss:  -15.9462
# Total loss:  -0.0521 | PDE Loss:  -0.0521 | Function Loss:  -15.9457
# Total loss:  -0.0645 | PDE Loss:  -0.0645 | Function Loss:  -15.9454
# Total loss:  -0.0815 | PDE Loss:  -0.0815 | Function Loss:  -15.9442
# Total loss:  -0.097 | PDE Loss:  -0.097 | Function Loss:  -15.9398
# Total loss:  -0.1051 | PDE Loss:  -0.1051 | Function Loss:  -15.9404
# Total loss:  -0.11 | PDE Loss:  -0.11 | Function Loss:  -15.9394
# Total loss:  -0.1153 | PDE Loss:  -0.1153 | Function Loss:  -15.9401
# Total loss:  -0.1203 | PDE Loss:  -0.1203 | Function Loss:  -15.9393
# Total loss:  -0.1264 | PDE Loss:  -0.1264 | Function Loss:  -15.9391
# Total loss:  -0.1346 | PDE Loss:  -0.1346 | Function Loss:  -15.9389
# Total loss:  -0.1489 | PDE Loss:  -0.1489 | Function Loss:  -15.9388
# Total loss:  -0.1609 | PDE Loss:  -0.1609 | Function Loss:  -15.9395
# Total loss:  -0.1694 | PDE Loss:  -0.1694 | Function Loss:  -15.9401
# Total loss:  -0.1774 | PDE Loss:  -0.1774 | Function Loss:  -15.9355
# Total loss:  -0.1911 | PDE Loss:  -0.1911 | Function Loss:  -15.9407
# Total loss:  -0.206 | PDE Loss:  -0.206 | Function Loss:  -15.941
# Total loss:  -0.2193 | PDE Loss:  -0.2193 | Function Loss:  -15.941
# Total loss:  -0.2333 | PDE Loss:  -0.2333 | Function Loss:  -15.9414
# Total loss:  -0.2485 | PDE Loss:  -0.2485 | Function Loss:  -15.9423
# Total loss:  -0.2362 | PDE Loss:  -0.2362 | Function Loss:  -15.9418
# Total loss:  -0.256 | PDE Loss:  -0.256 | Function Loss:  -15.9423
# Total loss:  -0.2635 | PDE Loss:  -0.2635 | Function Loss:  -15.9416
# Total loss:  -0.2738 | PDE Loss:  -0.2738 | Function Loss:  -15.9435
# Total loss:  -0.2824 | PDE Loss:  -0.2824 | Function Loss:  -15.9409
# Total loss:  -0.2882 | PDE Loss:  -0.2882 | Function Loss:  -15.941
# Total loss:  -0.2951 | PDE Loss:  -0.2951 | Function Loss:  -15.9417
# Total loss:  -0.3044 | PDE Loss:  -0.3044 | Function Loss:  -15.9454
# Total loss:  -0.3082 | PDE Loss:  -0.3082 | Function Loss:  -15.9459
# Total loss:  -0.3124 | PDE Loss:  -0.3124 | Function Loss:  -15.9484
# Total loss:  -0.3175 | PDE Loss:  -0.3175 | Function Loss:  -15.9491
# Total loss:  -0.3214 | PDE Loss:  -0.3214 | Function Loss:  -15.9502
# Total loss:  -0.3282 | PDE Loss:  -0.3282 | Function Loss:  -15.9503
# Total loss:  -0.3342 | PDE Loss:  -0.3342 | Function Loss:  -15.9502
# Total loss:  -0.3406 | PDE Loss:  -0.3406 | Function Loss:  -15.9496
# Total loss:  -0.3448 | PDE Loss:  -0.3448 | Function Loss:  -15.9499
# Total loss:  -0.3501 | PDE Loss:  -0.3501 | Function Loss:  -15.9496
# Total loss:  -0.3588 | PDE Loss:  -0.3588 | Function Loss:  -15.9496
# Total loss:  -0.3645 | PDE Loss:  -0.3645 | Function Loss:  -15.9482
# Total loss:  -0.37 | PDE Loss:  -0.37 | Function Loss:  -15.9486
# Total loss:  -0.3752 | PDE Loss:  -0.3752 | Function Loss:  -15.9487
# Total loss:  -0.3806 | PDE Loss:  -0.3806 | Function Loss:  -15.9488
# Total loss:  -0.3845 | PDE Loss:  -0.3845 | Function Loss:  -15.9492
# Total loss:  -0.3869 | PDE Loss:  -0.3869 | Function Loss:  -15.9475
# Total loss:  -0.3906 | PDE Loss:  -0.3906 | Function Loss:  -15.9477
# Total loss:  -0.3941 | PDE Loss:  -0.3941 | Function Loss:  -15.9476
# Total loss:  -0.3999 | PDE Loss:  -0.3999 | Function Loss:  -15.9472
# Total loss:  -0.4097 | PDE Loss:  -0.4097 | Function Loss:  -15.9456
# Total loss:  -0.416 | PDE Loss:  -0.416 | Function Loss:  -15.9469
# Total loss:  -0.4182 | PDE Loss:  -0.4182 | Function Loss:  -15.9462
# Total loss:  -0.42 | PDE Loss:  -0.42 | Function Loss:  -15.9463
# Total loss:  -0.422 | PDE Loss:  -0.422 | Function Loss:  -15.9466
# Total loss:  -0.4244 | PDE Loss:  -0.4244 | Function Loss:  -15.9469
# Total loss:  -0.428 | PDE Loss:  -0.428 | Function Loss:  -15.9465
# Total loss:  -0.4337 | PDE Loss:  -0.4337 | Function Loss:  -15.9466
# Total loss:  -0.4402 | PDE Loss:  -0.4402 | Function Loss:  -15.9464
# Total loss:  -0.447 | PDE Loss:  -0.447 | Function Loss:  -15.9465
# Total loss:  -0.4545 | PDE Loss:  -0.4545 | Function Loss:  -15.9467
# Total loss:  -0.461 | PDE Loss:  -0.461 | Function Loss:  -15.9463
# Total loss:  -0.4639 | PDE Loss:  -0.4639 | Function Loss:  -15.9479
# Total loss:  -0.4681 | PDE Loss:  -0.4681 | Function Loss:  -15.9471
# Total loss:  -0.4714 | PDE Loss:  -0.4714 | Function Loss:  -15.9469
# Total loss:  -0.4748 | PDE Loss:  -0.4748 | Function Loss:  -15.9464
# Total loss:  -0.4783 | PDE Loss:  -0.4783 | Function Loss:  -15.9469
# Total loss:  -0.4811 | PDE Loss:  -0.4811 | Function Loss:  -15.9458
# Total loss:  -0.4835 | PDE Loss:  -0.4835 | Function Loss:  -15.9461
# Total loss:  -0.4878 | PDE Loss:  -0.4878 | Function Loss:  -15.9468
# Total loss:  -0.4979 | PDE Loss:  -0.4979 | Function Loss:  -15.9482
# Total loss:  -0.5101 | PDE Loss:  -0.5101 | Function Loss:  -15.9499
# Total loss:  -0.5249 | PDE Loss:  -0.5249 | Function Loss:  -15.9512
# Total loss:  -0.5406 | PDE Loss:  -0.5406 | Function Loss:  -15.9526
# Total loss:  -0.5496 | PDE Loss:  -0.5496 | Function Loss:  -15.9521
# Total loss:  -0.5586 | PDE Loss:  -0.5586 | Function Loss:  -15.9534
# Total loss:  -0.5646 | PDE Loss:  -0.5646 | Function Loss:  -15.9531
# Total loss:  -0.5687 | PDE Loss:  -0.5687 | Function Loss:  -15.9532
# Total loss:  -0.5717 | PDE Loss:  -0.5717 | Function Loss:  -15.9523
# Total loss:  -0.5741 | PDE Loss:  -0.5741 | Function Loss:  -15.9517
# Total loss:  -0.5769 | PDE Loss:  -0.5769 | Function Loss:  -15.9509
# Total loss:  -0.5799 | PDE Loss:  -0.5799 | Function Loss:  -15.9503
# Total loss:  -0.5837 | PDE Loss:  -0.5837 | Function Loss:  -15.95
# Total loss:  -0.5889 | PDE Loss:  -0.5889 | Function Loss:  -15.9499
# Total loss:  -0.5934 | PDE Loss:  -0.5934 | Function Loss:  -15.9505
# Total loss:  -0.5964 | PDE Loss:  -0.5964 | Function Loss:  -15.9513
# Total loss:  -0.5983 | PDE Loss:  -0.5983 | Function Loss:  -15.9517
# Total loss:  -0.6012 | PDE Loss:  -0.6012 | Function Loss:  -15.9526
# Total loss:  -0.606 | PDE Loss:  -0.606 | Function Loss:  -15.9536
# Total loss:  -0.6138 | PDE Loss:  -0.6138 | Function Loss:  -15.9537
# Total loss:  -0.62 | PDE Loss:  -0.62 | Function Loss:  -15.9547
# Total loss:  -0.6276 | PDE Loss:  -0.6276 | Function Loss:  -15.9546
# Total loss:  -0.635 | PDE Loss:  -0.635 | Function Loss:  -15.9532
# Total loss:  -0.6414 | PDE Loss:  -0.6414 | Function Loss:  -15.9522
# Total loss:  -0.6456 | PDE Loss:  -0.6456 | Function Loss:  -15.9505
# Total loss:  -0.6484 | PDE Loss:  -0.6484 | Function Loss:  -15.9501
# Total loss:  -0.651 | PDE Loss:  -0.651 | Function Loss:  -15.9502
# Total loss:  -0.6549 | PDE Loss:  -0.6549 | Function Loss:  -15.9502
# Total loss:  -0.661 | PDE Loss:  -0.661 | Function Loss:  -15.9503
# Total loss:  -0.6683 | PDE Loss:  -0.6683 | Function Loss:  -15.9502
# Total loss:  -0.6748 | PDE Loss:  -0.6748 | Function Loss:  -15.9503
# Total loss:  -0.682 | PDE Loss:  -0.682 | Function Loss:  -15.9502
# Total loss:  -0.6874 | PDE Loss:  -0.6874 | Function Loss:  -15.9511
# Total loss:  -0.6927 | PDE Loss:  -0.6927 | Function Loss:  -15.9502
# Total loss:  -0.6975 | PDE Loss:  -0.6975 | Function Loss:  -15.9506
# Total loss:  -0.7054 | PDE Loss:  -0.7054 | Function Loss:  -15.9509
# Total loss:  -0.7137 | PDE Loss:  -0.7137 | Function Loss:  -15.9501
# Total loss:  -0.7182 | PDE Loss:  -0.7182 | Function Loss:  -15.9502
# Total loss:  -0.7208 | PDE Loss:  -0.7208 | Function Loss:  -15.9497
# Total loss:  -0.723 | PDE Loss:  -0.723 | Function Loss:  -15.9494
# Total loss:  -0.7244 | PDE Loss:  -0.7244 | Function Loss:  -15.9493
# Total loss:  -0.7253 | PDE Loss:  -0.7253 | Function Loss:  -15.9493
# Total loss:  -0.7269 | PDE Loss:  -0.7269 | Function Loss:  -15.9491
# Total loss:  -0.7292 | PDE Loss:  -0.7292 | Function Loss:  -15.9489
# Total loss:  -0.7323 | PDE Loss:  -0.7323 | Function Loss:  -15.9487
# Total loss:  -0.7363 | PDE Loss:  -0.7363 | Function Loss:  -15.9485
# Total loss:  -0.7415 | PDE Loss:  -0.7415 | Function Loss:  -15.9478
# Total loss:  -0.7475 | PDE Loss:  -0.7475 | Function Loss:  -15.9478
# Total loss:  -0.7537 | PDE Loss:  -0.7537 | Function Loss:  -15.9469
# Total loss:  -0.7603 | PDE Loss:  -0.7603 | Function Loss:  -15.9468
# Total loss:  -0.7657 | PDE Loss:  -0.7657 | Function Loss:  -15.9464
# Total loss:  -0.7709 | PDE Loss:  -0.7709 | Function Loss:  -15.9462
# Total loss:  -0.7765 | PDE Loss:  -0.7765 | Function Loss:  -15.9462
# Total loss:  -0.7815 | PDE Loss:  -0.7815 | Function Loss:  -15.9459
# Total loss:  -0.7851 | PDE Loss:  -0.7851 | Function Loss:  -15.946
# Total loss:  -0.7872 | PDE Loss:  -0.7872 | Function Loss:  -15.9458
# Total loss:  -0.7888 | PDE Loss:  -0.7888 | Function Loss:  -15.9462
# Total loss:  -0.7905 | PDE Loss:  -0.7905 | Function Loss:  -15.9459
# Total loss:  -0.7931 | PDE Loss:  -0.7931 | Function Loss:  -15.9458
# Total loss:  -0.7976 | PDE Loss:  -0.7976 | Function Loss:  -15.9454
# Total loss:  -0.8022 | PDE Loss:  -0.8022 | Function Loss:  -15.9456
# Total loss:  -0.8062 | PDE Loss:  -0.8062 | Function Loss:  -15.9451
# Total loss:  -0.8109 | PDE Loss:  -0.8109 | Function Loss:  -15.9457
# Total loss:  -0.8151 | PDE Loss:  -0.8151 | Function Loss:  -15.9463
# Total loss:  -0.8186 | PDE Loss:  -0.8186 | Function Loss:  -15.9468
# Total loss:  -0.8219 | PDE Loss:  -0.8219 | Function Loss:  -15.9468
# Total loss:  -0.829 | PDE Loss:  -0.829 | Function Loss:  -15.947
# Total loss:  -0.8375 | PDE Loss:  -0.8375 | Function Loss:  -15.9468
# Total loss:  -0.8486 | PDE Loss:  -0.8486 | Function Loss:  -15.9471
# Total loss:  -0.8125 | PDE Loss:  -0.8125 | Function Loss:  -15.9429
# Total loss:  -0.8525 | PDE Loss:  -0.8525 | Function Loss:  -15.9462
# Total loss:  -0.8591 | PDE Loss:  -0.8591 | Function Loss:  -15.9459
# Total loss:  -0.8651 | PDE Loss:  -0.8651 | Function Loss:  -15.9457
# Total loss:  -0.8696 | PDE Loss:  -0.8696 | Function Loss:  -15.9452
# Total loss:  -0.8722 | PDE Loss:  -0.8722 | Function Loss:  -15.9451
# Total loss:  -0.874 | PDE Loss:  -0.874 | Function Loss:  -15.9444
# Total loss:  -0.8754 | PDE Loss:  -0.8754 | Function Loss:  -15.9445
# Total loss:  -0.8766 | PDE Loss:  -0.8766 | Function Loss:  -15.9441
# Total loss:  -0.8775 | PDE Loss:  -0.8775 | Function Loss:  -15.9441
# Total loss:  -0.8784 | PDE Loss:  -0.8784 | Function Loss:  -15.9442
# Total loss:  -0.8797 | PDE Loss:  -0.8797 | Function Loss:  -15.9443
# Total loss:  -0.8821 | PDE Loss:  -0.8821 | Function Loss:  -15.9444
# Total loss:  -0.8863 | PDE Loss:  -0.8863 | Function Loss:  -15.9445
# Total loss:  -0.8912 | PDE Loss:  -0.8912 | Function Loss:  -15.9445
# Total loss:  -0.8978 | PDE Loss:  -0.8978 | Function Loss:  -15.9455
# Total loss:  -0.8503 | PDE Loss:  -0.8503 | Function Loss:  -15.9401
# Total loss:  -0.9031 | PDE Loss:  -0.9031 | Function Loss:  -15.9445
# Total loss:  -0.9062 | PDE Loss:  -0.9062 | Function Loss:  -15.9445
# Total loss:  -0.9125 | PDE Loss:  -0.9125 | Function Loss:  -15.9447
# Total loss:  -0.9175 | PDE Loss:  -0.9175 | Function Loss:  -15.944
# Total loss:  -0.9221 | PDE Loss:  -0.9221 | Function Loss:  -15.9445
# Total loss:  -0.924 | PDE Loss:  -0.924 | Function Loss:  -15.9437
# Total loss:  -0.926 | PDE Loss:  -0.926 | Function Loss:  -15.9438
# Total loss:  -0.9271 | PDE Loss:  -0.9271 | Function Loss:  -15.9437
# Total loss:  -0.9283 | PDE Loss:  -0.9283 | Function Loss:  -15.9437
# Total loss:  -0.9298 | PDE Loss:  -0.9298 | Function Loss:  -15.9437
# Total loss:  -0.9317 | PDE Loss:  -0.9317 | Function Loss:  -15.9436
# Total loss:  -0.9337 | PDE Loss:  -0.9337 | Function Loss:  -15.9434
# Total loss:  -0.9359 | PDE Loss:  -0.9359 | Function Loss:  -15.9439
# Total loss:  -0.9377 | PDE Loss:  -0.9377 | Function Loss:  -15.9434
# Total loss:  -0.9392 | PDE Loss:  -0.9392 | Function Loss:  -15.9434
# Total loss:  -0.9406 | PDE Loss:  -0.9406 | Function Loss:  -15.9434
# Total loss:  -0.942 | PDE Loss:  -0.942 | Function Loss:  -15.9434
# Total loss:  -0.9431 | PDE Loss:  -0.9431 | Function Loss:  -15.9434
# Total loss:  -0.9439 | PDE Loss:  -0.9439 | Function Loss:  -15.9434
# Total loss:  -0.9447 | PDE Loss:  -0.9447 | Function Loss:  -15.9433
# Total loss:  -0.9456 | PDE Loss:  -0.9456 | Function Loss:  -15.9435
# Total loss:  -0.9465 | PDE Loss:  -0.9465 | Function Loss:  -15.9435
# Total loss:  -0.9473 | PDE Loss:  -0.9473 | Function Loss:  -15.9436
# Total loss:  -0.9481 | PDE Loss:  -0.9481 | Function Loss:  -15.9436
# Total loss:  -0.9493 | PDE Loss:  -0.9493 | Function Loss:  -15.9437
# Total loss:  -0.9505 | PDE Loss:  -0.9505 | Function Loss:  -15.9436
# Total loss:  -0.9522 | PDE Loss:  -0.9522 | Function Loss:  -15.9435
# Total loss:  -0.9542 | PDE Loss:  -0.9542 | Function Loss:  -15.9433
# Total loss:  -0.9567 | PDE Loss:  -0.9567 | Function Loss:  -15.943
# Total loss:  -0.9596 | PDE Loss:  -0.9596 | Function Loss:  -15.9427
# Total loss:  -0.9631 | PDE Loss:  -0.9631 | Function Loss:  -15.9424
# Total loss:  -0.9668 | PDE Loss:  -0.9668 | Function Loss:  -15.9425
# Total loss:  -0.9723 | PDE Loss:  -0.9723 | Function Loss:  -15.9419
# Total loss:  -0.9782 | PDE Loss:  -0.9782 | Function Loss:  -15.9424
# Total loss:  -0.9826 | PDE Loss:  -0.9826 | Function Loss:  -15.9424
# Total loss:  -0.9862 | PDE Loss:  -0.9862 | Function Loss:  -15.9424
# Total loss:  -0.9907 | PDE Loss:  -0.9907 | Function Loss:  -15.9426
# Total loss:  -0.9967 | PDE Loss:  -0.9967 | Function Loss:  -15.9423
# Total loss:  -0.9982 | PDE Loss:  -0.9982 | Function Loss:  -15.9444
# Total loss:  -1.0012 | PDE Loss:  -1.0012 | Function Loss:  -15.9434
# Total loss:  -1.007 | PDE Loss:  -1.007 | Function Loss:  -15.9432
# Total loss:  -1.0144 | PDE Loss:  -1.0144 | Function Loss:  -15.9431
# Total loss:  -1.0245 | PDE Loss:  -1.0245 | Function Loss:  -15.9435
# Total loss:  -1.0325 | PDE Loss:  -1.0325 | Function Loss:  -15.9437
# Total loss:  -1.0375 | PDE Loss:  -1.0375 | Function Loss:  -15.9422
# Total loss:  -1.0416 | PDE Loss:  -1.0416 | Function Loss:  -15.9449
# Total loss:  -1.0465 | PDE Loss:  -1.0465 | Function Loss:  -15.9444
# Total loss:  -1.0485 | PDE Loss:  -1.0485 | Function Loss:  -15.9439
# Total loss:  -1.0499 | PDE Loss:  -1.0499 | Function Loss:  -15.9436
# Total loss:  -1.0521 | PDE Loss:  -1.0521 | Function Loss:  -15.9432
# Total loss:  -1.0561 | PDE Loss:  -1.0561 | Function Loss:  -15.9431
# Total loss:  -1.0602 | PDE Loss:  -1.0602 | Function Loss:  -15.9428
# Total loss:  -1.0628 | PDE Loss:  -1.0628 | Function Loss:  -15.9418
# Total loss:  -1.0684 | PDE Loss:  -1.0684 | Function Loss:  -15.942
# Total loss:  -1.0747 | PDE Loss:  -1.0747 | Function Loss:  -15.9423
# Total loss:  -1.0785 | PDE Loss:  -1.0785 | Function Loss:  -15.9429
# Total loss:  -1.0818 | PDE Loss:  -1.0818 | Function Loss:  -15.9431
# Total loss:  -1.0838 | PDE Loss:  -1.0838 | Function Loss:  -15.9433
# Total loss:  -1.0849 | PDE Loss:  -1.0849 | Function Loss:  -15.9436
# Total loss:  -1.0863 | PDE Loss:  -1.0863 | Function Loss:  -15.9436
# Total loss:  -1.0878 | PDE Loss:  -1.0878 | Function Loss:  -15.9435
# Total loss:  -1.0895 | PDE Loss:  -1.0895 | Function Loss:  -15.9437
# Total loss:  -1.0912 | PDE Loss:  -1.0912 | Function Loss:  -15.9435
# Total loss:  -1.0926 | PDE Loss:  -1.0926 | Function Loss:  -15.9435
# Total loss:  -1.0943 | PDE Loss:  -1.0943 | Function Loss:  -15.9436
# Total loss:  -1.0956 | PDE Loss:  -1.0956 | Function Loss:  -15.9433
# Total loss:  -1.0982 | PDE Loss:  -1.0982 | Function Loss:  -15.9435
# Total loss:  -1.1002 | PDE Loss:  -1.1002 | Function Loss:  -15.9433
# Total loss:  -1.1024 | PDE Loss:  -1.1024 | Function Loss:  -15.9438
# Total loss:  -1.1042 | PDE Loss:  -1.1042 | Function Loss:  -15.9438
# Total loss:  -1.1054 | PDE Loss:  -1.1054 | Function Loss:  -15.9439
# Total loss:  -1.1067 | PDE Loss:  -1.1067 | Function Loss:  -15.944
# Total loss:  -1.1088 | PDE Loss:  -1.1088 | Function Loss:  -15.9439
# Total loss:  -1.1099 | PDE Loss:  -1.1099 | Function Loss:  -15.9444
# Total loss:  -1.1105 | PDE Loss:  -1.1105 | Function Loss:  -15.9442
# Total loss:  -1.1126 | PDE Loss:  -1.1126 | Function Loss:  -15.9441
# Total loss:  -1.1147 | PDE Loss:  -1.1147 | Function Loss:  -15.944
# Total loss:  -1.1163 | PDE Loss:  -1.1163 | Function Loss:  -15.9439
# Total loss:  -1.1177 | PDE Loss:  -1.1177 | Function Loss:  -15.944
# Total loss:  -1.1188 | PDE Loss:  -1.1188 | Function Loss:  -15.9436
# Total loss:  -1.1196 | PDE Loss:  -1.1196 | Function Loss:  -15.9439
# Total loss:  -1.1204 | PDE Loss:  -1.1204 | Function Loss:  -15.9438
# Total loss:  -1.123 | PDE Loss:  -1.123 | Function Loss:  -15.9438
# Total loss:  -1.1258 | PDE Loss:  -1.1258 | Function Loss:  -15.9437
# Total loss:  -1.1282 | PDE Loss:  -1.1282 | Function Loss:  -15.9435
# Total loss:  -1.1299 | PDE Loss:  -1.1299 | Function Loss:  -15.9441
# Total loss:  -1.132 | PDE Loss:  -1.132 | Function Loss:  -15.9438
# Total loss:  -1.1334 | PDE Loss:  -1.1334 | Function Loss:  -15.9437
# Total loss:  -1.1347 | PDE Loss:  -1.1347 | Function Loss:  -15.9435
# Total loss:  -1.1361 | PDE Loss:  -1.1361 | Function Loss:  -15.9434
# Total loss:  -1.1382 | PDE Loss:  -1.1382 | Function Loss:  -15.9434
# Total loss:  -1.1417 | PDE Loss:  -1.1417 | Function Loss:  -15.9431
# Total loss:  -1.1449 | PDE Loss:  -1.1449 | Function Loss:  -15.9433
# Total loss:  -1.1508 | PDE Loss:  -1.1508 | Function Loss:  -15.943
# Total loss:  -1.1538 | PDE Loss:  -1.1538 | Function Loss:  -15.9433
# Total loss:  -1.1591 | PDE Loss:  -1.1591 | Function Loss:  -15.9428
# Total loss:  -1.1624 | PDE Loss:  -1.1624 | Function Loss:  -15.943
# Total loss:  -1.1647 | PDE Loss:  -1.1647 | Function Loss:  -15.9429
# Total loss:  -1.1682 | PDE Loss:  -1.1682 | Function Loss:  -15.9428
# Total loss:  -1.1733 | PDE Loss:  -1.1733 | Function Loss:  -15.9428
# Total loss:  -1.1793 | PDE Loss:  -1.1793 | Function Loss:  -15.9427
# Total loss:  -1.1866 | PDE Loss:  -1.1866 | Function Loss:  -15.943
# Total loss:  -1.1927 | PDE Loss:  -1.1927 | Function Loss:  -15.9431
# Total loss:  -1.1976 | PDE Loss:  -1.1976 | Function Loss:  -15.9434
# Total loss:  -1.1989 | PDE Loss:  -1.1989 | Function Loss:  -15.9438
# Total loss:  -1.2035 | PDE Loss:  -1.2035 | Function Loss:  -15.9441
# Total loss:  -1.2071 | PDE Loss:  -1.2071 | Function Loss:  -15.9445
# Total loss:  -1.2101 | PDE Loss:  -1.2101 | Function Loss:  -15.9446
# Total loss:  -1.2135 | PDE Loss:  -1.2135 | Function Loss:  -15.9447
# Total loss:  -1.2176 | PDE Loss:  -1.2176 | Function Loss:  -15.9448
# Total loss:  -1.2204 | PDE Loss:  -1.2204 | Function Loss:  -15.9447
# Total loss:  -1.2225 | PDE Loss:  -1.2225 | Function Loss:  -15.9449
# Total loss:  -1.225 | PDE Loss:  -1.225 | Function Loss:  -15.9445
# Total loss:  -1.2271 | PDE Loss:  -1.2271 | Function Loss:  -15.9446
# Total loss:  -1.2314 | PDE Loss:  -1.2314 | Function Loss:  -15.9447
# Total loss:  -1.236 | PDE Loss:  -1.236 | Function Loss:  -15.9446
# Total loss:  -1.2398 | PDE Loss:  -1.2398 | Function Loss:  -15.9446
# Total loss:  -1.2424 | PDE Loss:  -1.2424 | Function Loss:  -15.9447
# Total loss:  -1.2436 | PDE Loss:  -1.2436 | Function Loss:  -15.9445
# Total loss:  -1.2443 | PDE Loss:  -1.2443 | Function Loss:  -15.9447
# Total loss:  -1.2447 | PDE Loss:  -1.2447 | Function Loss:  -15.9447
# Total loss:  -1.2452 | PDE Loss:  -1.2452 | Function Loss:  -15.9447
# Total loss:  -1.2458 | PDE Loss:  -1.2458 | Function Loss:  -15.9446
# Total loss:  -1.2467 | PDE Loss:  -1.2467 | Function Loss:  -15.9446
# Total loss:  -1.2481 | PDE Loss:  -1.2481 | Function Loss:  -15.9445
# Total loss:  -1.2502 | PDE Loss:  -1.2502 | Function Loss:  -15.9444
# Total loss:  -1.253 | PDE Loss:  -1.253 | Function Loss:  -15.9443
# Total loss:  -1.2567 | PDE Loss:  -1.2567 | Function Loss:  -15.9442
# Total loss:  -1.2603 | PDE Loss:  -1.2603 | Function Loss:  -15.9442
# Total loss:  -1.2632 | PDE Loss:  -1.2632 | Function Loss:  -15.9442
# Total loss:  -1.2657 | PDE Loss:  -1.2657 | Function Loss:  -15.9443
# Total loss:  -1.2678 | PDE Loss:  -1.2678 | Function Loss:  -15.9443
# Total loss:  -1.2708 | PDE Loss:  -1.2708 | Function Loss:  -15.9444
# Total loss:  -1.2754 | PDE Loss:  -1.2754 | Function Loss:  -15.9442
# Total loss:  -1.2814 | PDE Loss:  -1.2814 | Function Loss:  -15.9444
# Total loss:  -1.2867 | PDE Loss:  -1.2867 | Function Loss:  -15.9439
# Total loss:  -1.2917 | PDE Loss:  -1.2917 | Function Loss:  -15.944
# Total loss:  -1.2961 | PDE Loss:  -1.2961 | Function Loss:  -15.944
# Total loss:  -1.2998 | PDE Loss:  -1.2998 | Function Loss:  -15.9442
# Total loss:  -1.3016 | PDE Loss:  -1.3016 | Function Loss:  -15.9439
# Total loss:  -1.3022 | PDE Loss:  -1.3022 | Function Loss:  -15.9439
# Total loss:  -1.3025 | PDE Loss:  -1.3025 | Function Loss:  -15.9441
# Total loss:  -1.3031 | PDE Loss:  -1.3031 | Function Loss:  -15.9441
# Total loss:  -1.3041 | PDE Loss:  -1.3041 | Function Loss:  -15.9442
# Total loss:  -1.3051 | PDE Loss:  -1.3051 | Function Loss:  -15.9442
# Total loss:  -1.3059 | PDE Loss:  -1.3059 | Function Loss:  -15.9442
# Total loss:  -1.3069 | PDE Loss:  -1.3069 | Function Loss:  -15.9442
# Total loss:  -1.308 | PDE Loss:  -1.308 | Function Loss:  -15.9442
# Total loss:  -1.3091 | PDE Loss:  -1.3091 | Function Loss:  -15.9442
# Total loss:  -1.3104 | PDE Loss:  -1.3104 | Function Loss:  -15.9442
# Total loss:  -1.3117 | PDE Loss:  -1.3117 | Function Loss:  -15.9443
# Total loss:  -1.3136 | PDE Loss:  -1.3136 | Function Loss:  -15.9444
# Total loss:  -1.3153 | PDE Loss:  -1.3153 | Function Loss:  -15.9445
# Total loss:  -1.3173 | PDE Loss:  -1.3173 | Function Loss:  -15.9446
# Total loss:  -1.3188 | PDE Loss:  -1.3188 | Function Loss:  -15.9448
# Total loss:  -1.3212 | PDE Loss:  -1.3212 | Function Loss:  -15.9447
# Total loss:  -1.3234 | PDE Loss:  -1.3234 | Function Loss:  -15.9449
# Total loss:  -1.3241 | PDE Loss:  -1.3241 | Function Loss:  -15.9447
# Total loss:  -1.3249 | PDE Loss:  -1.3249 | Function Loss:  -15.9448
# Total loss:  -1.3282 | PDE Loss:  -1.3282 | Function Loss:  -15.9447
# Total loss:  -1.3322 | PDE Loss:  -1.3322 | Function Loss:  -15.9444
# Total loss:  -1.337 | PDE Loss:  -1.337 | Function Loss:  -15.9444
# Total loss:  -1.342 | PDE Loss:  -1.342 | Function Loss:  -15.9443
# Total loss:  -1.3474 | PDE Loss:  -1.3474 | Function Loss:  -15.9446
# Total loss:  -1.2719 | PDE Loss:  -1.2719 | Function Loss:  -15.9419
# Total loss:  -1.3509 | PDE Loss:  -1.3509 | Function Loss:  -15.9442
# Total loss:  -1.3533 | PDE Loss:  -1.3533 | Function Loss:  -15.9437
# Total loss:  -1.3553 | PDE Loss:  -1.3553 | Function Loss:  -15.9439
# Total loss:  -1.3598 | PDE Loss:  -1.3598 | Function Loss:  -15.9442
# Total loss:  -1.3681 | PDE Loss:  -1.3681 | Function Loss:  -15.9447
# Total loss:  -1.3731 | PDE Loss:  -1.3731 | Function Loss:  -15.9447
# Total loss:  -1.3763 | PDE Loss:  -1.3763 | Function Loss:  -15.945
# Total loss:  -1.3783 | PDE Loss:  -1.3783 | Function Loss:  -15.9451
# Total loss:  -1.3793 | PDE Loss:  -1.3793 | Function Loss:  -15.9448
# Total loss:  -1.3815 | PDE Loss:  -1.3815 | Function Loss:  -15.9449
# Total loss:  -1.3827 | PDE Loss:  -1.3827 | Function Loss:  -15.945
# Total loss:  -1.3839 | PDE Loss:  -1.3839 | Function Loss:  -15.9449
# Total loss:  -1.3861 | PDE Loss:  -1.3861 | Function Loss:  -15.9449
# Total loss:  -1.3884 | PDE Loss:  -1.3884 | Function Loss:  -15.9447
# Total loss:  -1.3908 | PDE Loss:  -1.3908 | Function Loss:  -15.9446
# Total loss:  -1.3946 | PDE Loss:  -1.3946 | Function Loss:  -15.9446
# Total loss:  -1.3964 | PDE Loss:  -1.3964 | Function Loss:  -15.944
# Total loss:  -1.4005 | PDE Loss:  -1.4005 | Function Loss:  -15.9444
# Total loss:  -1.4031 | PDE Loss:  -1.4031 | Function Loss:  -15.9446
# Total loss:  -1.4059 | PDE Loss:  -1.4059 | Function Loss:  -15.9447
# Total loss:  -1.4108 | PDE Loss:  -1.4108 | Function Loss:  -15.9449
# Total loss:  -1.4144 | PDE Loss:  -1.4144 | Function Loss:  -15.9446
# Total loss:  -1.4168 | PDE Loss:  -1.4168 | Function Loss:  -15.9446
# Total loss:  -1.4203 | PDE Loss:  -1.4203 | Function Loss:  -15.9444
# Total loss:  -1.4249 | PDE Loss:  -1.4249 | Function Loss:  -15.9442
# Total loss:  -1.4285 | PDE Loss:  -1.4285 | Function Loss:  -15.9439
# Total loss:  -1.4334 | PDE Loss:  -1.4334 | Function Loss:  -15.9437
# Total loss:  -1.4328 | PDE Loss:  -1.4328 | Function Loss:  -15.9429
# Total loss:  -1.4356 | PDE Loss:  -1.4356 | Function Loss:  -15.9433
# Total loss:  -1.4414 | PDE Loss:  -1.4414 | Function Loss:  -15.9434
# Total loss:  -1.4414 | PDE Loss:  -1.4414 | Function Loss:  -15.9428
# Total loss:  -1.444 | PDE Loss:  -1.444 | Function Loss:  -15.9431
# Total loss:  -1.4477 | PDE Loss:  -1.4477 | Function Loss:  -15.9436
# Total loss:  -1.4507 | PDE Loss:  -1.4507 | Function Loss:  -15.9435
# Total loss:  -1.4546 | PDE Loss:  -1.4546 | Function Loss:  -15.9434
# Total loss:  -1.458 | PDE Loss:  -1.458 | Function Loss:  -15.9435
# Total loss:  -1.4614 | PDE Loss:  -1.4614 | Function Loss:  -15.9435
# Total loss:  -1.4646 | PDE Loss:  -1.4646 | Function Loss:  -15.9436
# Total loss:  -1.4662 | PDE Loss:  -1.4662 | Function Loss:  -15.9438
# Total loss:  -1.4688 | PDE Loss:  -1.4688 | Function Loss:  -15.9438
# Total loss:  -1.472 | PDE Loss:  -1.472 | Function Loss:  -15.9436
# Total loss:  -1.4754 | PDE Loss:  -1.4754 | Function Loss:  -15.9436
# Total loss:  -1.4786 | PDE Loss:  -1.4786 | Function Loss:  -15.943
# Total loss:  -1.48 | PDE Loss:  -1.48 | Function Loss:  -15.9431
# Total loss:  -1.4809 | PDE Loss:  -1.4809 | Function Loss:  -15.943
# Total loss:  -1.4819 | PDE Loss:  -1.4819 | Function Loss:  -15.9429
# Total loss:  -1.4833 | PDE Loss:  -1.4833 | Function Loss:  -15.9428
# Total loss:  -1.4843 | PDE Loss:  -1.4843 | Function Loss:  -15.9427
# Total loss:  -1.4852 | PDE Loss:  -1.4852 | Function Loss:  -15.9427
# Total loss:  -1.4861 | PDE Loss:  -1.4861 | Function Loss:  -15.9426
# Total loss:  -1.487 | PDE Loss:  -1.487 | Function Loss:  -15.9426
# Total loss:  -1.4882 | PDE Loss:  -1.4882 | Function Loss:  -15.9424
# Total loss:  -1.4891 | PDE Loss:  -1.4891 | Function Loss:  -15.9426
# Total loss:  -1.4908 | PDE Loss:  -1.4908 | Function Loss:  -15.9424
# Total loss:  -1.4925 | PDE Loss:  -1.4925 | Function Loss:  -15.9423
# Total loss:  -1.4946 | PDE Loss:  -1.4946 | Function Loss:  -15.9422
# Total loss:  -1.4973 | PDE Loss:  -1.4973 | Function Loss:  -15.9423
# Total loss:  -1.4999 | PDE Loss:  -1.4999 | Function Loss:  -15.9424
# Total loss:  -1.5011 | PDE Loss:  -1.5011 | Function Loss:  -15.9426
# Total loss:  -1.5024 | PDE Loss:  -1.5024 | Function Loss:  -15.9425
# Total loss:  -1.5039 | PDE Loss:  -1.5039 | Function Loss:  -15.9426
# Total loss:  -1.5049 | PDE Loss:  -1.5049 | Function Loss:  -15.9425
# Total loss:  -1.5057 | PDE Loss:  -1.5057 | Function Loss:  -15.9425
# Total loss:  -1.5065 | PDE Loss:  -1.5065 | Function Loss:  -15.9425
# Total loss:  -1.5074 | PDE Loss:  -1.5074 | Function Loss:  -15.9424
# Total loss:  -1.5087 | PDE Loss:  -1.5087 | Function Loss:  -15.9423
# Total loss:  -1.5107 | PDE Loss:  -1.5107 | Function Loss:  -15.9421
# Total loss:  -1.5052 | PDE Loss:  -1.5052 | Function Loss:  -15.9426
# Total loss:  -1.5117 | PDE Loss:  -1.5117 | Function Loss:  -15.9422
# Total loss:  -1.5138 | PDE Loss:  -1.5138 | Function Loss:  -15.9421
# Total loss:  -1.5163 | PDE Loss:  -1.5163 | Function Loss:  -15.9418
# Total loss:  -1.5186 | PDE Loss:  -1.5186 | Function Loss:  -15.9418
# Total loss:  -1.5206 | PDE Loss:  -1.5206 | Function Loss:  -15.9415
# Total loss:  -1.5215 | PDE Loss:  -1.5215 | Function Loss:  -15.9416
# Total loss:  -1.5227 | PDE Loss:  -1.5227 | Function Loss:  -15.9416
# Total loss:  -1.5241 | PDE Loss:  -1.5241 | Function Loss:  -15.9416
# Total loss:  -1.5255 | PDE Loss:  -1.5255 | Function Loss:  -15.9415
# Total loss:  -1.5266 | PDE Loss:  -1.5266 | Function Loss:  -15.9415
# Total loss:  -1.5275 | PDE Loss:  -1.5275 | Function Loss:  -15.9414
# Total loss:  -1.5281 | PDE Loss:  -1.5281 | Function Loss:  -15.9414
# Total loss:  -1.529 | PDE Loss:  -1.529 | Function Loss:  -15.9413
# Total loss:  -1.5297 | PDE Loss:  -1.5297 | Function Loss:  -15.9413
# Total loss:  -1.531 | PDE Loss:  -1.531 | Function Loss:  -15.9412
# Total loss:  -1.5324 | PDE Loss:  -1.5324 | Function Loss:  -15.9412
# Total loss:  -1.5339 | PDE Loss:  -1.5339 | Function Loss:  -15.941
# Total loss:  -1.5354 | PDE Loss:  -1.5354 | Function Loss:  -15.9411
# Total loss:  -1.5368 | PDE Loss:  -1.5368 | Function Loss:  -15.9411
# Total loss:  -1.5397 | PDE Loss:  -1.5397 | Function Loss:  -15.9412
# Total loss:  -1.5426 | PDE Loss:  -1.5426 | Function Loss:  -15.9412
# Total loss:  -1.5453 | PDE Loss:  -1.5453 | Function Loss:  -15.9413
# Total loss:  -1.5478 | PDE Loss:  -1.5478 | Function Loss:  -15.9412
# Total loss:  -1.5495 | PDE Loss:  -1.5495 | Function Loss:  -15.9413
# Total loss:  -1.5505 | PDE Loss:  -1.5505 | Function Loss:  -15.9413
# Total loss:  -1.552 | PDE Loss:  -1.552 | Function Loss:  -15.9413
# Total loss:  -1.5536 | PDE Loss:  -1.5536 | Function Loss:  -15.9413
# Total loss:  -1.555 | PDE Loss:  -1.555 | Function Loss:  -15.9413
# Total loss:  -1.5562 | PDE Loss:  -1.5562 | Function Loss:  -15.9413
# Total loss:  -1.5572 | PDE Loss:  -1.5572 | Function Loss:  -15.9414
# Total loss:  -1.5582 | PDE Loss:  -1.5582 | Function Loss:  -15.9413
# Total loss:  -1.559 | PDE Loss:  -1.559 | Function Loss:  -15.9413
# Total loss:  -1.5599 | PDE Loss:  -1.5599 | Function Loss:  -15.9412
# Total loss:  -1.5607 | PDE Loss:  -1.5607 | Function Loss:  -15.9411
# Total loss:  -1.5616 | PDE Loss:  -1.5616 | Function Loss:  -15.9411
# Total loss:  -1.5624 | PDE Loss:  -1.5624 | Function Loss:  -15.9409
# Total loss:  -1.5632 | PDE Loss:  -1.5632 | Function Loss:  -15.9409
# Total loss:  -1.564 | PDE Loss:  -1.564 | Function Loss:  -15.9408
# Total loss:  -1.565 | PDE Loss:  -1.565 | Function Loss:  -15.9408
# Total loss:  -1.5664 | PDE Loss:  -1.5664 | Function Loss:  -15.9408
# Total loss:  -1.5683 | PDE Loss:  -1.5683 | Function Loss:  -15.9409
# Total loss:  -1.5707 | PDE Loss:  -1.5707 | Function Loss:  -15.941
# Total loss:  -1.5731 | PDE Loss:  -1.5731 | Function Loss:  -15.9413
# Total loss:  -1.5761 | PDE Loss:  -1.5761 | Function Loss:  -15.9415
# Total loss:  -1.5789 | PDE Loss:  -1.5789 | Function Loss:  -15.9418
# Total loss:  -1.5831 | PDE Loss:  -1.5831 | Function Loss:  -15.942
# Total loss:  -1.5859 | PDE Loss:  -1.5859 | Function Loss:  -15.9422
# Total loss:  -1.5886 | PDE Loss:  -1.5886 | Function Loss:  -15.9421
# Total loss:  -1.5904 | PDE Loss:  -1.5904 | Function Loss:  -15.942
# Total loss:  -1.5916 | PDE Loss:  -1.5916 | Function Loss:  -15.9418
# Total loss:  -1.5924 | PDE Loss:  -1.5924 | Function Loss:  -15.9416
# Total loss:  -1.5932 | PDE Loss:  -1.5932 | Function Loss:  -15.9416
# Total loss:  -1.5942 | PDE Loss:  -1.5942 | Function Loss:  -15.9415
# Total loss:  -1.5956 | PDE Loss:  -1.5956 | Function Loss:  -15.9414
# Total loss:  -1.597 | PDE Loss:  -1.597 | Function Loss:  -15.9414
# Total loss:  -1.5985 | PDE Loss:  -1.5985 | Function Loss:  -15.9414
# Total loss:  -1.6003 | PDE Loss:  -1.6003 | Function Loss:  -15.9415
# Total loss:  -1.6026 | PDE Loss:  -1.6026 | Function Loss:  -15.9417
# Total loss:  -1.6046 | PDE Loss:  -1.6046 | Function Loss:  -15.9419
# Total loss:  -1.6064 | PDE Loss:  -1.6064 | Function Loss:  -15.9421
# Total loss:  -1.608 | PDE Loss:  -1.608 | Function Loss:  -15.9424
# Total loss:  -1.6091 | PDE Loss:  -1.6091 | Function Loss:  -15.9424
# Total loss:  -1.6099 | PDE Loss:  -1.6099 | Function Loss:  -15.9425
# Total loss:  -1.6106 | PDE Loss:  -1.6106 | Function Loss:  -15.9425
# Total loss:  -1.6113 | PDE Loss:  -1.6113 | Function Loss:  -15.9425
# Total loss:  -1.6118 | PDE Loss:  -1.6118 | Function Loss:  -15.9425
# Total loss:  -1.6123 | PDE Loss:  -1.6123 | Function Loss:  -15.9425
# Total loss:  -1.6129 | PDE Loss:  -1.6129 | Function Loss:  -15.9424
# Total loss:  -1.6135 | PDE Loss:  -1.6135 | Function Loss:  -15.9424
# Total loss:  -1.6141 | PDE Loss:  -1.6141 | Function Loss:  -15.9424
# Total loss:  -1.6149 | PDE Loss:  -1.6149 | Function Loss:  -15.9423
# Total loss:  -1.6156 | PDE Loss:  -1.6156 | Function Loss:  -15.9422
# Total loss:  -1.6163 | PDE Loss:  -1.6163 | Function Loss:  -15.9421
# Total loss:  -1.6172 | PDE Loss:  -1.6172 | Function Loss:  -15.9421
# Total loss:  -1.6183 | PDE Loss:  -1.6183 | Function Loss:  -15.942
# Total loss:  -1.6197 | PDE Loss:  -1.6197 | Function Loss:  -15.9419
# Total loss:  -1.6213 | PDE Loss:  -1.6213 | Function Loss:  -15.9419
# Total loss:  -1.6231 | PDE Loss:  -1.6231 | Function Loss:  -15.9419
# Total loss:  -1.625 | PDE Loss:  -1.625 | Function Loss:  -15.9419
# Total loss:  -1.6267 | PDE Loss:  -1.6267 | Function Loss:  -15.942
# Total loss:  -1.6282 | PDE Loss:  -1.6282 | Function Loss:  -15.942
# Total loss:  -1.6293 | PDE Loss:  -1.6293 | Function Loss:  -15.9421
# Total loss:  -1.6303 | PDE Loss:  -1.6303 | Function Loss:  -15.942
# Total loss:  -1.6312 | PDE Loss:  -1.6312 | Function Loss:  -15.9421
# Total loss:  -1.6322 | PDE Loss:  -1.6322 | Function Loss:  -15.9421
# Total loss:  -1.6334 | PDE Loss:  -1.6334 | Function Loss:  -15.9421
# Total loss:  -1.6346 | PDE Loss:  -1.6346 | Function Loss:  -15.9421
# Total loss:  -1.6359 | PDE Loss:  -1.6359 | Function Loss:  -15.9421
# Total loss:  -1.6371 | PDE Loss:  -1.6371 | Function Loss:  -15.942
# Total loss:  -1.638 | PDE Loss:  -1.638 | Function Loss:  -15.942
# Total loss:  -1.6393 | PDE Loss:  -1.6393 | Function Loss:  -15.9419
# Total loss:  -1.6406 | PDE Loss:  -1.6406 | Function Loss:  -15.9418
# Total loss:  -1.6416 | PDE Loss:  -1.6416 | Function Loss:  -15.9419
# Total loss:  -1.6423 | PDE Loss:  -1.6423 | Function Loss:  -15.9418
# Total loss:  -1.6429 | PDE Loss:  -1.6429 | Function Loss:  -15.9418
# Total loss:  -1.6436 | PDE Loss:  -1.6436 | Function Loss:  -15.9418
# Total loss:  -1.6445 | PDE Loss:  -1.6445 | Function Loss:  -15.9418
# Total loss:  -1.6452 | PDE Loss:  -1.6452 | Function Loss:  -15.9417
# Total loss:  -1.6459 | PDE Loss:  -1.6459 | Function Loss:  -15.9417
# Total loss:  -1.6467 | PDE Loss:  -1.6467 | Function Loss:  -15.9417
# Total loss:  -1.6476 | PDE Loss:  -1.6476 | Function Loss:  -15.9417
# Total loss:  -1.6486 | PDE Loss:  -1.6486 | Function Loss:  -15.9416
# Total loss:  -1.6497 | PDE Loss:  -1.6497 | Function Loss:  -15.9416
# Total loss:  -1.6507 | PDE Loss:  -1.6507 | Function Loss:  -15.9416
# Total loss:  -1.6523 | PDE Loss:  -1.6523 | Function Loss:  -15.9417
# Total loss:  -1.6543 | PDE Loss:  -1.6543 | Function Loss:  -15.9415
# Total loss:  -1.6554 | PDE Loss:  -1.6554 | Function Loss:  -15.9415
# Total loss:  -1.6562 | PDE Loss:  -1.6562 | Function Loss:  -15.9415
# Total loss:  -1.6573 | PDE Loss:  -1.6573 | Function Loss:  -15.9414
# Total loss:  -1.6582 | PDE Loss:  -1.6582 | Function Loss:  -15.9414
# Total loss:  -1.6591 | PDE Loss:  -1.6591 | Function Loss:  -15.9413
# Total loss:  -1.66 | PDE Loss:  -1.66 | Function Loss:  -15.9413
# Total loss:  -1.661 | PDE Loss:  -1.661 | Function Loss:  -15.9413
# Total loss:  -1.6625 | PDE Loss:  -1.6625 | Function Loss:  -15.9413
# Total loss:  -1.6636 | PDE Loss:  -1.6636 | Function Loss:  -15.9414
# Total loss:  -1.6651 | PDE Loss:  -1.6651 | Function Loss:  -15.9415
# Total loss:  -1.6669 | PDE Loss:  -1.6669 | Function Loss:  -15.9416
# Total loss:  -1.6671 | PDE Loss:  -1.6671 | Function Loss:  -15.9416
# Total loss:  -1.6678 | PDE Loss:  -1.6678 | Function Loss:  -15.9416
# Total loss:  -1.6689 | PDE Loss:  -1.6689 | Function Loss:  -15.9417
# Total loss:  -1.6695 | PDE Loss:  -1.6695 | Function Loss:  -15.9417
# Total loss:  -1.6703 | PDE Loss:  -1.6703 | Function Loss:  -15.9417
# Total loss:  -1.6711 | PDE Loss:  -1.6711 | Function Loss:  -15.9417
# Total loss:  -1.672 | PDE Loss:  -1.672 | Function Loss:  -15.9416
# Total loss:  -1.6729 | PDE Loss:  -1.6729 | Function Loss:  -15.9416
# Total loss:  -1.674 | PDE Loss:  -1.674 | Function Loss:  -15.9414
# Total loss:  -1.6747 | PDE Loss:  -1.6747 | Function Loss:  -15.9414
# Total loss:  -1.6751 | PDE Loss:  -1.6751 | Function Loss:  -15.9414
# Total loss:  -1.6758 | PDE Loss:  -1.6758 | Function Loss:  -15.9413
# Total loss:  -1.6766 | PDE Loss:  -1.6766 | Function Loss:  -15.9413
# Total loss:  -1.6771 | PDE Loss:  -1.6771 | Function Loss:  -15.9414
# Total loss:  -1.6785 | PDE Loss:  -1.6785 | Function Loss:  -15.9415
# Total loss:  -1.6749 | PDE Loss:  -1.6749 | Function Loss:  -15.9417
# Total loss:  -1.6788 | PDE Loss:  -1.6788 | Function Loss:  -15.9415
# Total loss:  -1.6799 | PDE Loss:  -1.6799 | Function Loss:  -15.9416
# Total loss:  -1.6808 | PDE Loss:  -1.6808 | Function Loss:  -15.9416
# Total loss:  -1.6817 | PDE Loss:  -1.6817 | Function Loss:  -15.9417
# Total loss:  -1.6827 | PDE Loss:  -1.6827 | Function Loss:  -15.9417
# Total loss:  -1.6843 | PDE Loss:  -1.6843 | Function Loss:  -15.9416
# Total loss:  -1.6858 | PDE Loss:  -1.6858 | Function Loss:  -15.9415
# Total loss:  -1.6868 | PDE Loss:  -1.6868 | Function Loss:  -15.9415
# Total loss:  -1.688 | PDE Loss:  -1.688 | Function Loss:  -15.9414
# Total loss:  -1.6885 | PDE Loss:  -1.6885 | Function Loss:  -15.9414
# Total loss:  -1.6893 | PDE Loss:  -1.6893 | Function Loss:  -15.9415
# Total loss:  -1.69 | PDE Loss:  -1.69 | Function Loss:  -15.9416
# Total loss:  -1.6904 | PDE Loss:  -1.6904 | Function Loss:  -15.9416
# ...
# Total loss:  -2.7332 | PDE Loss:  -2.7332 | Function Loss:  -15.9414
# Total loss:  -2.7334 | PDE Loss:  -2.7334 | Function Loss:  -15.9414
# Total loss:  -2.7341 | PDE Loss:  -2.7341 | Function Loss:  -15.9414
# Total loss:  -2.7347 | PDE Loss:  -2.7347 | Function Loss:  -15.9415
# Total loss:  -2.7354 | PDE Loss:  -2.7354 | Function Loss:  -15.9414
# Total loss:  -2.736 | PDE Loss:  -2.736 | Function Loss:  -15.9415
# Total loss:  -2.7368 | PDE Loss:  -2.7368 | Function Loss:  -15.9414
# Total loss:  -2.7375 | PDE Loss:  -2.7375 | Function Loss:  -15.9414
# Total loss:  -2.7383 | PDE Loss:  -2.7383 | Function Loss:  -15.9414
# Total loss:  -2.7397 | PDE Loss:  -2.7397 | Function Loss:  -15.9414
# Total loss:  -2.7418 | PDE Loss:  -2.7418 | Function Loss:  -15.9414
# Total loss:  -2.7433 | PDE Loss:  -2.7433 | Function Loss:  -15.9413
# Total loss:  -2.744 | PDE Loss:  -2.744 | Function Loss:  -15.9414
# Total loss:  -2.745 | PDE Loss:  -2.745 | Function Loss:  -15.9414
# Total loss:  -2.7459 | PDE Loss:  -2.7459 | Function Loss:  -15.9414
# Total loss:  -2.7467 | PDE Loss:  -2.7467 | Function Loss:  -15.9414
# Total loss:  -2.7476 | PDE Loss:  -2.7476 | Function Loss:  -15.9414
# Total loss:  -2.7467 | PDE Loss:  -2.7467 | Function Loss:  -15.9414
# Total loss:  -2.7479 | PDE Loss:  -2.7479 | Function Loss:  -15.9414
# Total loss:  -2.7485 | PDE Loss:  -2.7485 | Function Loss:  -15.9414
# Total loss:  -2.7492 | PDE Loss:  -2.7492 | Function Loss:  -15.9413
# Total loss:  -2.7502 | PDE Loss:  -2.7502 | Function Loss:  -15.9414
# Total loss:  -2.7512 | PDE Loss:  -2.7512 | Function Loss:  -15.9414
# Total loss:  -2.7523 | PDE Loss:  -2.7523 | Function Loss:  -15.9414
# Total loss:  -2.7533 | PDE Loss:  -2.7533 | Function Loss:  -15.9414
# Total loss:  -2.7539 | PDE Loss:  -2.7539 | Function Loss:  -15.9414
# Total loss:  -2.7544 | PDE Loss:  -2.7544 | Function Loss:  -15.9414
# Total loss:  -2.7553 | PDE Loss:  -2.7553 | Function Loss:  -15.9414
# Total loss:  -2.7563 | PDE Loss:  -2.7563 | Function Loss:  -15.9414
# Total loss:  -2.7572 | PDE Loss:  -2.7572 | Function Loss:  -15.9414
# Total loss:  -2.7584 | PDE Loss:  -2.7584 | Function Loss:  -15.9414
# Total loss:  -2.7594 | PDE Loss:  -2.7594 | Function Loss:  -15.9414
# Total loss:  -2.7606 | PDE Loss:  -2.7606 | Function Loss:  -15.9414
# Total loss:  -2.7617 | PDE Loss:  -2.7617 | Function Loss:  -15.9414
# Total loss:  -2.7616 | PDE Loss:  -2.7616 | Function Loss:  -15.9413
# Total loss:  -2.7622 | PDE Loss:  -2.7622 | Function Loss:  -15.9414
# Total loss:  -2.7632 | PDE Loss:  -2.7632 | Function Loss:  -15.9414
# Total loss:  -2.7638 | PDE Loss:  -2.7638 | Function Loss:  -15.9414
# Total loss:  -2.7651 | PDE Loss:  -2.7651 | Function Loss:  -15.9414
# Total loss:  -2.7661 | PDE Loss:  -2.7661 | Function Loss:  -15.9415
# Total loss:  -2.767 | PDE Loss:  -2.767 | Function Loss:  -15.9415
# Total loss:  -2.7681 | PDE Loss:  -2.7681 | Function Loss:  -15.9415
# Total loss:  -2.7692 | PDE Loss:  -2.7692 | Function Loss:  -15.9415
# Total loss:  -2.7706 | PDE Loss:  -2.7706 | Function Loss:  -15.9416
# Total loss:  -2.7721 | PDE Loss:  -2.7721 | Function Loss:  -15.9416
# Total loss:  -2.7738 | PDE Loss:  -2.7738 | Function Loss:  -15.9415
# Total loss:  -2.7757 | PDE Loss:  -2.7757 | Function Loss:  -15.9414
# Total loss:  -2.7747 | PDE Loss:  -2.7747 | Function Loss:  -15.9415
# Total loss:  -2.7769 | PDE Loss:  -2.7769 | Function Loss:  -15.9414
# Total loss:  -2.7783 | PDE Loss:  -2.7783 | Function Loss:  -15.9414
# Total loss:  -2.7804 | PDE Loss:  -2.7804 | Function Loss:  -15.9413
# Total loss:  -2.7818 | PDE Loss:  -2.7818 | Function Loss:  -15.9413
# Total loss:  -2.7828 | PDE Loss:  -2.7828 | Function Loss:  -15.9414
# Total loss:  -2.7838 | PDE Loss:  -2.7838 | Function Loss:  -15.9413
# Total loss:  -2.7847 | PDE Loss:  -2.7847 | Function Loss:  -15.9413
# Total loss:  -2.7859 | PDE Loss:  -2.7859 | Function Loss:  -15.9413
# Total loss:  -2.7866 | PDE Loss:  -2.7866 | Function Loss:  -15.9413
# Total loss:  -2.7872 | PDE Loss:  -2.7872 | Function Loss:  -15.9413
# Total loss:  -2.7876 | PDE Loss:  -2.7876 | Function Loss:  -15.9413
# Total loss:  -2.788 | PDE Loss:  -2.788 | Function Loss:  -15.9413
# Total loss:  -2.7883 | PDE Loss:  -2.7883 | Function Loss:  -15.9413
# Total loss:  -2.7886 | PDE Loss:  -2.7886 | Function Loss:  -15.9413
# Total loss:  -2.7889 | PDE Loss:  -2.7889 | Function Loss:  -15.9413
# Total loss:  -2.7892 | PDE Loss:  -2.7892 | Function Loss:  -15.9413
# Total loss:  -2.7896 | PDE Loss:  -2.7896 | Function Loss:  -15.9413
# Total loss:  -2.7899 | PDE Loss:  -2.7899 | Function Loss:  -15.9413
# Total loss:  -2.7901 | PDE Loss:  -2.7901 | Function Loss:  -15.9413
# Total loss:  -2.7904 | PDE Loss:  -2.7904 | Function Loss:  -15.9413
# Total loss:  -2.7907 | PDE Loss:  -2.7907 | Function Loss:  -15.9413
# Total loss:  -2.7912 | PDE Loss:  -2.7912 | Function Loss:  -15.9413
# Total loss:  -2.764 | PDE Loss:  -2.764 | Function Loss:  -15.9417
# Total loss:  -2.7913 | PDE Loss:  -2.7913 | Function Loss:  -15.9413
# Total loss:  -2.7916 | PDE Loss:  -2.7916 | Function Loss:  -15.9413
# Total loss:  -2.792 | PDE Loss:  -2.792 | Function Loss:  -15.9413
# Total loss:  -2.7923 | PDE Loss:  -2.7923 | Function Loss:  -15.9413
# Total loss:  -2.7925 | PDE Loss:  -2.7925 | Function Loss:  -15.9413
# Total loss:  -2.7927 | PDE Loss:  -2.7927 | Function Loss:  -15.9413
# Total loss:  -2.7929 | PDE Loss:  -2.7929 | Function Loss:  -15.9413
# Total loss:  -2.7931 | PDE Loss:  -2.7931 | Function Loss:  -15.9413
# Total loss:  -2.7933 | PDE Loss:  -2.7933 | Function Loss:  -15.9413
# Total loss:  -2.7935 | PDE Loss:  -2.7935 | Function Loss:  -15.9413
# Total loss:  -2.7936 | PDE Loss:  -2.7936 | Function Loss:  -15.9413
# Total loss:  -2.7938 | PDE Loss:  -2.7938 | Function Loss:  -15.9413
# Total loss:  -2.794 | PDE Loss:  -2.794 | Function Loss:  -15.9413
# Total loss:  -2.7941 | PDE Loss:  -2.7941 | Function Loss:  -15.9413
# Total loss:  -2.7943 | PDE Loss:  -2.7943 | Function Loss:  -15.9413
# Total loss:  -2.7944 | PDE Loss:  -2.7944 | Function Loss:  -15.9413
# Total loss:  -2.7946 | PDE Loss:  -2.7946 | Function Loss:  -15.9413
# Total loss:  -2.7947 | PDE Loss:  -2.7947 | Function Loss:  -15.9413
# Total loss:  -2.7949 | PDE Loss:  -2.7949 | Function Loss:  -15.9413
# Total loss:  -2.795 | PDE Loss:  -2.795 | Function Loss:  -15.9413
# Total loss:  -2.7952 | PDE Loss:  -2.7952 | Function Loss:  -15.9413
# Total loss:  -2.7954 | PDE Loss:  -2.7954 | Function Loss:  -15.9413
# Total loss:  -2.7955 | PDE Loss:  -2.7955 | Function Loss:  -15.9413
# Total loss:  -2.7956 | PDE Loss:  -2.7956 | Function Loss:  -15.9413
# Total loss:  -2.7958 | PDE Loss:  -2.7958 | Function Loss:  -15.9413
# Total loss:  -2.7959 | PDE Loss:  -2.7959 | Function Loss:  -15.9413
# Total loss:  -2.796 | PDE Loss:  -2.796 | Function Loss:  -15.9413
# Total loss:  -2.7961 | PDE Loss:  -2.7961 | Function Loss:  -15.9413
# Total loss:  -2.7962 | PDE Loss:  -2.7962 | Function Loss:  -15.9413
# Total loss:  -2.7964 | PDE Loss:  -2.7964 | Function Loss:  -15.9413
# Total loss:  -2.7964 | PDE Loss:  -2.7964 | Function Loss:  -15.9413
# Total loss:  -2.7966 | PDE Loss:  -2.7966 | Function Loss:  -15.9413
# Total loss:  -2.7967 | PDE Loss:  -2.7967 | Function Loss:  -15.9413
# Total loss:  -2.7969 | PDE Loss:  -2.7969 | Function Loss:  -15.9413
# Total loss:  -2.797 | PDE Loss:  -2.797 | Function Loss:  -15.9413
# Total loss:  -2.7971 | PDE Loss:  -2.7971 | Function Loss:  -15.9413
# Total loss:  -2.7972 | PDE Loss:  -2.7972 | Function Loss:  -15.9413
# Total loss:  -2.7974 | PDE Loss:  -2.7974 | Function Loss:  -15.9413
# Total loss:  -2.7975 | PDE Loss:  -2.7975 | Function Loss:  -15.9413
# Total loss:  -2.7976 | PDE Loss:  -2.7976 | Function Loss:  -15.9413
# Total loss:  -2.7977 | PDE Loss:  -2.7977 | Function Loss:  -15.9413
# Total loss:  -2.7977 | PDE Loss:  -2.7977 | Function Loss:  -15.9412
# Total loss:  -2.7978 | PDE Loss:  -2.7978 | Function Loss:  -15.9412
# Total loss:  -2.798 | PDE Loss:  -2.798 | Function Loss:  -15.9412
# Total loss:  -2.798 | PDE Loss:  -2.798 | Function Loss:  -15.9412
# Total loss:  -2.7981 | PDE Loss:  -2.7981 | Function Loss:  -15.9412
# Total loss:  -2.7982 | PDE Loss:  -2.7982 | Function Loss:  -15.9412
# Total loss:  -2.7984 | PDE Loss:  -2.7984 | Function Loss:  -15.9412
# Total loss:  -2.7986 | PDE Loss:  -2.7986 | Function Loss:  -15.9412
# Total loss:  -2.7988 | PDE Loss:  -2.7988 | Function Loss:  -15.9412
# Total loss:  -2.7991 | PDE Loss:  -2.7991 | Function Loss:  -15.9412
# Total loss:  -2.7993 | PDE Loss:  -2.7993 | Function Loss:  -15.9412
# Total loss:  -2.7995 | PDE Loss:  -2.7995 | Function Loss:  -15.9412
# Total loss:  -2.7996 | PDE Loss:  -2.7996 | Function Loss:  -15.9412
# Total loss:  -2.7998 | PDE Loss:  -2.7998 | Function Loss:  -15.9412
# Total loss:  -2.7999 | PDE Loss:  -2.7999 | Function Loss:  -15.9412
# Total loss:  -2.8 | PDE Loss:  -2.8 | Function Loss:  -15.9412
# Total loss:  -2.8001 | PDE Loss:  -2.8001 | Function Loss:  -15.9412
# Total loss:  -2.8002 | PDE Loss:  -2.8002 | Function Loss:  -15.9412
# Total loss:  -2.8003 | PDE Loss:  -2.8003 | Function Loss:  -15.9412
# Total loss:  -2.8005 | PDE Loss:  -2.8005 | Function Loss:  -15.9412
# Total loss:  -2.8008 | PDE Loss:  -2.8008 | Function Loss:  -15.9412
# Total loss:  -2.801 | PDE Loss:  -2.801 | Function Loss:  -15.9413
# Total loss:  -2.8012 | PDE Loss:  -2.8012 | Function Loss:  -15.9413
# Total loss:  -2.8014 | PDE Loss:  -2.8014 | Function Loss:  -15.9413
# Total loss:  -2.8017 | PDE Loss:  -2.8017 | Function Loss:  -15.9413
# Total loss:  -2.8021 | PDE Loss:  -2.8021 | Function Loss:  -15.9413
# Total loss:  -2.8024 | PDE Loss:  -2.8024 | Function Loss:  -15.9413
# Total loss:  -2.8028 | PDE Loss:  -2.8028 | Function Loss:  -15.9413
# Total loss:  -2.8033 | PDE Loss:  -2.8033 | Function Loss:  -15.9413
# Total loss:  -2.8037 | PDE Loss:  -2.8037 | Function Loss:  -15.9413
# Total loss:  -2.8041 | PDE Loss:  -2.8041 | Function Loss:  -15.9413
# Total loss:  -2.8045 | PDE Loss:  -2.8045 | Function Loss:  -15.9413
# Total loss:  -2.805 | PDE Loss:  -2.805 | Function Loss:  -15.9413
# Total loss:  -2.8056 | PDE Loss:  -2.8056 | Function Loss:  -15.9413
# Total loss:  -2.8062 | PDE Loss:  -2.8062 | Function Loss:  -15.9413
# Total loss:  -2.807 | PDE Loss:  -2.807 | Function Loss:  -15.9413
# Total loss:  -2.8077 | PDE Loss:  -2.8077 | Function Loss:  -15.9413
# Total loss:  -2.8081 | PDE Loss:  -2.8081 | Function Loss:  -15.9413
# Total loss:  -2.8086 | PDE Loss:  -2.8086 | Function Loss:  -15.9413
# Total loss:  -2.8089 | PDE Loss:  -2.8089 | Function Loss:  -15.9413
# Total loss:  -2.8092 | PDE Loss:  -2.8092 | Function Loss:  -15.9412
# Total loss:  -2.8094 | PDE Loss:  -2.8094 | Function Loss:  -15.9412
# Total loss:  -2.8096 | PDE Loss:  -2.8096 | Function Loss:  -15.9413
# Total loss:  -2.8098 | PDE Loss:  -2.8098 | Function Loss:  -15.9413
# Total loss:  -2.81 | PDE Loss:  -2.81 | Function Loss:  -15.9413
# Total loss:  -2.8101 | PDE Loss:  -2.8101 | Function Loss:  -15.9413
# Total loss:  -2.8103 | PDE Loss:  -2.8103 | Function Loss:  -15.9413
# Total loss:  -2.8105 | PDE Loss:  -2.8105 | Function Loss:  -15.9413
# Total loss:  -2.8107 | PDE Loss:  -2.8107 | Function Loss:  -15.9413
# Total loss:  -2.811 | PDE Loss:  -2.811 | Function Loss:  -15.9413
# Total loss:  -2.8113 | PDE Loss:  -2.8113 | Function Loss:  -15.9413
# Total loss:  -2.8117 | PDE Loss:  -2.8117 | Function Loss:  -15.9413
# Total loss:  -2.8119 | PDE Loss:  -2.8119 | Function Loss:  -15.9413
# Total loss:  -2.8122 | PDE Loss:  -2.8122 | Function Loss:  -15.9413
# Total loss:  -2.8125 | PDE Loss:  -2.8125 | Function Loss:  -15.9413
# Total loss:  -2.8127 | PDE Loss:  -2.8127 | Function Loss:  -15.9413
# Total loss:  -2.8127 | PDE Loss:  -2.8127 | Function Loss:  -15.9413
# Total loss:  -2.8128 | PDE Loss:  -2.8128 | Function Loss:  -15.9413
# Total loss:  -2.813 | PDE Loss:  -2.813 | Function Loss:  -15.9413
# Total loss:  -2.8131 | PDE Loss:  -2.8131 | Function Loss:  -15.9413
# Total loss:  -2.8132 | PDE Loss:  -2.8132 | Function Loss:  -15.9413
# Total loss:  -2.8134 | PDE Loss:  -2.8134 | Function Loss:  -15.9413
# Total loss:  -2.8137 | PDE Loss:  -2.8137 | Function Loss:  -15.9413
# Total loss:  -2.8139 | PDE Loss:  -2.8139 | Function Loss:  -15.9412
# Total loss:  -2.8142 | PDE Loss:  -2.8142 | Function Loss:  -15.9412
# Total loss:  -2.8146 | PDE Loss:  -2.8146 | Function Loss:  -15.9412
# Total loss:  -2.815 | PDE Loss:  -2.815 | Function Loss:  -15.9412
# Total loss:  -2.8154 | PDE Loss:  -2.8154 | Function Loss:  -15.9412
# Total loss:  -2.8157 | PDE Loss:  -2.8157 | Function Loss:  -15.9413
# Total loss:  -2.8161 | PDE Loss:  -2.8161 | Function Loss:  -15.9413
# Total loss:  -2.8164 | PDE Loss:  -2.8164 | Function Loss:  -15.9413
# Total loss:  -2.8167 | PDE Loss:  -2.8167 | Function Loss:  -15.9413
# Total loss:  -2.817 | PDE Loss:  -2.817 | Function Loss:  -15.9413
# Total loss:  -2.8172 | PDE Loss:  -2.8172 | Function Loss:  -15.9413
# Total loss:  -2.8174 | PDE Loss:  -2.8174 | Function Loss:  -15.9413
# Total loss:  -2.8178 | PDE Loss:  -2.8178 | Function Loss:  -15.9413
# Total loss:  -2.8181 | PDE Loss:  -2.8181 | Function Loss:  -15.9413
# Total loss:  -2.8185 | PDE Loss:  -2.8185 | Function Loss:  -15.9412
# Total loss:  -2.8188 | PDE Loss:  -2.8188 | Function Loss:  -15.9412
# Total loss:  -2.8191 | PDE Loss:  -2.8191 | Function Loss:  -15.9412
# Total loss:  -2.8194 | PDE Loss:  -2.8194 | Function Loss:  -15.9412
# Total loss:  -2.8198 | PDE Loss:  -2.8198 | Function Loss:  -15.9412
# Total loss:  -2.82 | PDE Loss:  -2.82 | Function Loss:  -15.9412
# Total loss:  -2.8204 | PDE Loss:  -2.8204 | Function Loss:  -15.9412
# Total loss:  -2.8206 | PDE Loss:  -2.8206 | Function Loss:  -15.9412
# Total loss:  -2.8208 | PDE Loss:  -2.8208 | Function Loss:  -15.9412
# Total loss:  -2.821 | PDE Loss:  -2.821 | Function Loss:  -15.9412
# Total loss:  -2.8212 | PDE Loss:  -2.8212 | Function Loss:  -15.9412
# Total loss:  -2.8213 | PDE Loss:  -2.8213 | Function Loss:  -15.9412
# Total loss:  -2.8214 | PDE Loss:  -2.8214 | Function Loss:  -15.9412
# Total loss:  -2.8215 | PDE Loss:  -2.8215 | Function Loss:  -15.9412
# Total loss:  -2.8217 | PDE Loss:  -2.8217 | Function Loss:  -15.9412
# Total loss:  -2.8217 | PDE Loss:  -2.8217 | Function Loss:  -15.9412
# Total loss:  -2.8218 | PDE Loss:  -2.8218 | Function Loss:  -15.9412
# Total loss:  -2.8219 | PDE Loss:  -2.8219 | Function Loss:  -15.9412
# Total loss:  -2.8211 | PDE Loss:  -2.8211 | Function Loss:  -15.9413
# Total loss:  -2.822 | PDE Loss:  -2.822 | Function Loss:  -15.9413
# Total loss:  -2.8221 | PDE Loss:  -2.8221 | Function Loss:  -15.9413
# Total loss:  -2.8223 | PDE Loss:  -2.8223 | Function Loss:  -15.9412
# Total loss:  -2.8224 | PDE Loss:  -2.8224 | Function Loss:  -15.9412
# Total loss:  -2.8225 | PDE Loss:  -2.8225 | Function Loss:  -15.9412
# Total loss:  -2.8227 | PDE Loss:  -2.8227 | Function Loss:  -15.9412
# Total loss:  -2.8229 | PDE Loss:  -2.8229 | Function Loss:  -15.9413
# Total loss:  -2.823 | PDE Loss:  -2.823 | Function Loss:  -15.9413
# Total loss:  -2.8233 | PDE Loss:  -2.8233 | Function Loss:  -15.9412
# Total loss:  -2.8235 | PDE Loss:  -2.8235 | Function Loss:  -15.9413
# Total loss:  -2.8237 | PDE Loss:  -2.8237 | Function Loss:  -15.9412
# Total loss:  -2.8238 | PDE Loss:  -2.8238 | Function Loss:  -15.9412
# Total loss:  -2.824 | PDE Loss:  -2.824 | Function Loss:  -15.9412
# Total loss:  -2.8242 | PDE Loss:  -2.8242 | Function Loss:  -15.9412
# Total loss:  -2.8244 | PDE Loss:  -2.8244 | Function Loss:  -15.9412
# Total loss:  -2.8212 | PDE Loss:  -2.8212 | Function Loss:  -15.9414
# Total loss:  -2.8244 | PDE Loss:  -2.8244 | Function Loss:  -15.9413
# Total loss:  -2.8244 | PDE Loss:  -2.8244 | Function Loss:  -15.9412
# Total loss:  -2.8244 | PDE Loss:  -2.8244 | Function Loss:  -15.9412
# Total loss:  -2.8244 | PDE Loss:  -2.8244 | Function Loss:  -15.9412
# Total loss:  -2.8244 | PDE Loss:  -2.8244 | Function Loss:  -15.9412
# Total loss:  -2.8244 | PDE Loss:  -2.8244 | Function Loss:  -15.9412
# Total loss:  -2.8244 | PDE Loss:  -2.8244 | Function Loss:  -15.9412
# Total loss:  -2.8244 | PDE Loss:  -2.8244 | Function Loss:  -15.9412
# Final Loss:  -2.8243966102600098

# %%
pinn.plotting()
# Out:
# L2 Relative Error Norm:  0.525711178779602 %
# L2 Relative Error Norm:  0.4923059046268463 %
# L2 Relative Error Norm:  0.5663449764251709 %
# L2 Relative Error Norm:  0.47866860032081604 %
# L2 Relative Error Norm:  0.4856765866279602 %
